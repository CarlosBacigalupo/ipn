# %%
# from os import walk, system
# #import _mysql
# import psycopg2 as mdb
import pyfits as pf
# import time
# import numpy as np
# import ephem
from pyraf import iraf
import glob
# import fileinput
# from matplotlib import *
# from pylab import *
# from mpl_toolkits.mplot3d import Axes3D
# import itertools
# import sys
# import galahParameters as gp

# %%
def shift_master(ref, master):
    """
    Find the shift between two images.
    returns the shift in y direction (along columns)
    """
    #make a narow copy of the reference flat and masterflat 
    iraf.imcopy(input="../"+ref+"[1990:2010,*]", output="tmp/masterflat_ref.fitscut",Stdout="/dev/null")
    iraf.imcopy(input="tmp/masterflat.fits[1990:2010,*]", output="tmp/masterflat.fitscut",Stdout="/dev/null")

    #find the shift with correlation
    iraf.images(_doprint=0,Stdout="/dev/null")
    iraf.immatch(_doprint=0,Stdout="/dev/null")

    shift=iraf.xregister(input="tmp/masterflat_ref.fitscut, tmp/masterflat.fitscut", reference="tmp/masterflat_ref.fitscut", regions='[*,*]', shifts="tmp/mastershift", output="", databasefmt="no", correlation="fourier", xwindow=3, ywindow=51, xcbox=21, ycbox=21, Stdout=1)

    shift=float(shift[-2].split()[-2])

    #Shift the list of apertures
    f=open(master, "r")
    o=open("database/aptmp_masterflat_s", "w")

    for line in f:
        l=line.split()
        if len(l)>0 and l[0]=='begin':
            l[-1]=str(float(l[-1])-shift)
            o.write(l[0]+"\t"+l[1]+"\t"+"tmp/masterflat_s"+"\t"+l[3]+"\t"+l[4]+"\t"+l[5]+"\n")
        elif len(l)>0 and l[0]=='center':
            l[-1]=str(float(l[-1])-shift)
            o.write("\t"+l[0]+"\t"+l[1]+"\t"+l[2]+"\n")
        elif len(l)>0 and l[0]=='image':
            o.write("\t"+"image"+"\t"+"tmp/masterflat_s"+"\n")
        else:
            o.write(line)

    f.close()
    o.close()

# %%
def extract(arcs, objs,ccd,mode=1):
    """
    mode=1: 1D extraction
    mode=2: 2D extraction
    """
    #apall na vseh luckah
    print " + identifing arcs"

    for i in arcs:
        iraf.hedit(images='tmp/arcs/'+i[1], fields='DISPAXIS', value=1, add='yes', verify='no', update='yes',Stdout="/dev/null")
        iraf.apall(input='tmp/arcs/%s' % (i[1]), referen='tmp/masterflat.fits', format='multispec', interac='no', find='no', recenter='no', resize='no', edit='no', trace='no', fittrac='no', extract='yes', extras='no', review='yes', lower=-3.0, upper=3.0, nsubaps=7, pfit="fit1d", Stdout="/dev/null")

    if mode==1:
        pass
    else:
        iraf.cd("tmp/arcs")
        geometry_prep(arcs,ccd)
        os.system("cp transformations* ../objs/")
        #sys.exit(0)
        iraf.cd("../..")
        for i in arcs:
            os.system("rm tmp/arcs/%s.ms.fits" % (i[1][:-5]))
            os.system("rm tmp/arcs/%s_cut*.fits" % (i[1][:-5]))
            os.system("rm tmp/arcs/%s_t*.fits" % (i[1][:-5]))
            pass

        os.system("rm tmp/arcs/calibrations/idarcs_cut*")
        os.system("rm tmp/arcs/arcs_cut*")

        #extract 2d arcs and objects
        for i in arcs:
            iraf.hedit(images='tmp/arcs/'+i[1], fields='DISPAXIS', value=1, add='yes', verify='no', update='yes',Stdout="/dev/null")
            iraf.apall(input='tmp/arcs/%s' % (i[1]), referen='tmp/masterflat.fits', format='multispec', interac='no', find='no', recenter='no', resize='no', edit='no', trace='no', fittrac='no', extract='yes', extras='no', review='yes', lower=-3.0, upper=3.0, nsubaps=7, pfit="fit1d", Stdout="/dev/null")
            #forget apertures
            for j in range(8,1000):
                iraf.hedit(images='tmp/arcs/%s.ms.fits' % (i[1][:-5]), fields="APNUM%s" % (str(j)), value='', delete="yes", verify="no", Stdout="/dev/null")

        for i in objs:
            iraf.hedit(images='tmp/objs/'+i[1], fields='DISPAXIS', value=1, add='yes', verify='no', update='yes',Stdout="/dev/null")
            iraf.apall(input='tmp/objs/%s' % (i[1]), referen='tmp/masterflat.fits', format='multispec', interac='no', find='no', recenter='no', resize='no', edit='no', trace='no', fittrac='no', extract='yes', extras='no', review='yes', lower=-3.0, upper=3.0, nsubaps=7, pfit="fit1d", Stdout="/dev/null")
            #forget apertures
            for j in range(8,1000):
                iraf.hedit(images='tmp/objs/%s.ms.fits' % (i[1][:-5]), fields="APNUM%s" % (str(j)), value='', delete="yes", verify="no", Stdout="/dev/null")

        iraf.cd("tmp/arcs")
        for ii in arcs:
            geometry_transform(ii)
        iraf.cd("../..")

        iraf.cd("tmp/objs")
        for ii in objs:
            geometry_transform(ii)
        iraf.cd("../..")

    #make normal 1d extraction and copy results into it
    for i in arcs:
        os.system("rm -f tmp/arcs/%s" % (i[1][:-5]+".ms.fits"))
        iraf.apall(input='tmp/arcs/%s' % (i[1]), referen='tmp/masterflat.fits', format='multispec', interac='no', find='no', recenter='no', resize='no', edit='no', trace='no', fittrac='no', extract='yes', extras='no', review='yes', lower=-3.0, upper=3.0, nsubaps=1, pfit="fit1d", Stdout="/dev/null")
        os.system("cp tmp/arcs/%s" % (i[1][:-5])+".ms.fits tmp/arcs/%s" % (i[1][:-5])+".ms2.fits")

        if mode==1:
            pass
        else:
            for j in range(1,393):
                os.system("rm -f tmp/copy_tmp.fits")
                try:
                    iraf.blkavg(input="tmp/arcs/"+i[1][:-5]+"_t%s.fits" % (str(j)), output="tmp/copy_tmp", option='sum', b1=1, b2=7, Stdout="/dev/null")
                    iraf.imcopy(input="tmp/copy_tmp", output="tmp/arcs/"+i[1][:-5]+".ms.fits[*,%s]" % (j), Stdout="/dev/null")
                except:
                    pass

    for i in objs:
        os.system("rm -f tmp/objs/%s" % (i[1][:-5]+".ms.fits"))
        iraf.apall(input='tmp/objs/%s' % (i[1]), referen='tmp/masterflat.fits', format='multispec', interac='no', find='no', recenter='no', resize='no', edit='no', trace='no', fittrac='no', extract='yes', extras='no', review='yes', lower=-3.0, upper=3.0, nsubaps=1, pfit="fit1d", Stdout="/dev/null")
        os.system("cp tmp/objs/%s" % (i[1][:-5])+".ms.fits tmp/objs/%s" % (i[1][:-5])+".ms2.fits")

        if mode==1:
            pass
        else:
            for j in range(1,393):
                os.system("rm -f tmp/copy_tmp.fits")
                try:
                    iraf.blkavg(input="tmp/objs/"+i[1][:-5]+"_t%s.fits" % (str(j)), output="tmp/copy_tmp", option='sum', b1=1, b2=7, Stdout="/dev/null")
                    iraf.imcopy(input="tmp/copy_tmp", output="tmp/objs/"+i[1][:-5]+".ms.fits[*,%s]" % (j), Stdout="/dev/null")
                except:
                    pass

# %% [markdown]
# ### BIAS

# %%
cd ~/Documents/HERMES/reductions/iraf/bias/140821/1
# Out:
# /Users/Carlos/Documents/HERMES/reductions/iraf/bias/140821

# %%
biases = glob.glob('*.fits')`

# %%
biases = ",".join(biases)

# %%
iraf.zerocombine(input=biases, output='masterbias', combine='median', reject='none', ccdtype='',Stdout="/dev/null")

# %%
cd ~/Documents/HERMES/reductions/iraf/HD1581/0_20aug/1/
# Out:
# /Users/Carlos/Documents/HERMES/reductions/iraf/HD1581/0_20aug/1

# %%
a = pf.open('20aug10052.fits')
a[0].header['RUNCMD']
# Out:
# 'ARC'

# %% [markdown]
# ### FLAT

# %%
flat = '20aug10034.fits'
masterflat = 'masterflat_blue0.fits'

# %%
iraf.noao(_doprint=0,Stdout="/dev/null")
iraf.imred(_doprint=0,Stdout="/dev/null")
iraf.ccdred(_doprint=0,Stdout="/dev/null")

# %%
#bias subtract
iraf.ccdproc(images=flat, ccdtype='', fixpix='no', oversca='no', trim='no', zerocor='yes', darkcor='no', flatcor='no', zero='masterbias',Stdout="/dev/null")

# %%
#apall on a flat field
print " + Extract masterflat"
iraf.noao(_doprint=0,Stdout="/dev/null")
iraf.twodspec(_doprint=0,Stdout="/dev/null")
iraf.apextract(_doprint=0,Stdout="/dev/null")
# Out:
#  + Extract masterflat

# %%
#adds DISPAXIS=1 to the header
iraf.hedit(images=flat, fields='DISPAXIS', value=1, add='yes', verify='no', update='yes',Stdout="/dev/null")

# %%
iraf.unlearn('apall') #restores initial paramenters to apall

# %%
shift_master(ap_ref[ccd], "database/ap%s" % ap_ref[ccd][:-5])

# %%
check=iraf.apall(input=flat, format='multispec', referen=flat, interac='no', find='no',
                 recenter='yes', resize='no', edit='yes', trace='yes', fittrac='yes',
                 extract='yes', extras='no', review='yes', line=2000, lower=-2, upper=2, 
                 nfind=392, maxsep=45, minsep=3, width=5, radius=2, ylevel=0.3, shift='yes', 
                 t_order=7, t_niter=10, t_low_r=3, t_high_r=3, t_sampl='1:4095', t_nlost=1, 
                 npeaks=392, bkg='no', b_order=7, nsum=-10,Stdout=1)
# Out:
# Not enough points traced for aperture 1 of 20aug10034

# %%
flat
# Out:
# '20aug10034.fits'

# %%
#create flats with different aperture widths
iraf.apall(input=flat, output='flat_1', referen=flat, format='multispec', interac='no', find='no', recenter='no', resize='yes', edit='no', trace='no', fittrac='no', extract='yes', extras='no', review='no', line=2000, lower=-1, upper=1, bkg='no', nsum=-10, ylevel="INDEF", llimit=-1, ulimit=1,Stdout="/dev/null")
# iraf.apall(input='tmp/masterflat.fits', output='tmp/flat_2', referen='tmp/masterflat.fits', format='multispec', interac='no', find='no', recenter='no', resize='yes', edit='no', trace='no', fittrac='no', extract='yes', extras='no', review='no', line=2000, lower=-2, upper=2, bkg='no', nsum=-10, ylevel="INDEF", llimit=-2, ulimit=2,Stdout="/dev/null")
# iraf.apall(input='tmp/masterflat.fits', output='tmp/flat_3', referen='tmp/masterflat.fits', format='multispec', interac='no', find='no', recenter='no', resize='yes', edit='no', trace='no', fittrac='no', extract='yes', extras='no', review='no', line=2000, lower=-3, upper=3, bkg='no', nsum=-10, ylevel="INDEF", llimit=-3, ulimit=3,Stdout="/dev/null")

# %%
#normalize different flats
iraf.noao(_doprint=0,Stdout="/dev/null")
iraf.onedspec(_doprint=0,Stdout="/dev/null")
iraf.continuum(input=flat, output='flat_1_norm', lines='*', bands='*', type='ratio', wavescale='no', interac='no', sample='1:4095', functio='spline3', order=13, low_rej=2, high_rej=2, niter=10,Stdout="/dev/null")
# iraf.continuum(input='tmp/flat_2', output='tmp/flat_2_norm', lines='*', bands='*', type='ratio', wavescale='no', interac='no', sample='1:4095', functio='spline3', order=13, low_rej=2, high_rej=2, niter=10,Stdout="/dev/null")
# iraf.continuum(input='tmp/flat_3', output='tmp/flat_3_norm', lines='*', bands='*', type='ratio', wavescale='no', interac='no', sample='1:4095', functio='spline3', order=13, low_rej=2, high_rej=2, niter=10,Stdout="/dev/null")

# %%
#combine normalized flats
# iraf.images(_doprint=0,Stdout="/dev/null")
# iraf.imutil(_doprint=0,Stdout="/dev/null")
# iraf.imarith(operand1='tmp/flat_1_norm', op='*', operand2=0.43, result='tmp/flat_1_norm2',Stdout="/dev/null")
# iraf.imarith(operand1='tmp/flat_2_norm', op='*', operand2=0.41, result='tmp/flat_2_norm2',Stdout="/dev/null")
# iraf.imarith(operand1='tmp/flat_3_norm', op='*', operand2=0.16, result='tmp/flat_3_norm2',Stdout="/dev/null")

# %%
iraf.imsum(input='*norm.fits', output='masterflat_norm.fits', option='sum',Stdout="/dev/null")

# %% [markdown]
# ### arcs

# %%
arc = '20aug10052.fits'
obj = '20aug10053.fits'

# %%
#find arcs
#     print " + Reducing arcs"
#     cur.execute("SELECT spec_path,name from fields where ymd=%s and ccd='%s' and obstype='ARC' and plate='%s'" % (ymd, ccd, plate))
#     arcs=cur.fetchall()

#     #find object frames
#     cur.execute("SELECT spec_path,name from fields where ymd=%s and ccd='%s' and obstype='OBJECT' and plate='%s'" % (ymd, ccd, plate))
#     objs=cur.fetchall()

#     #make a new list of objects if a list of exposures is given:
#     objs_new=[]
#     for i in objs:
#         #print i[0][-9:-5]
#         if (str(i[0][-9:-5]) in list_of_exp) or (list_of_exp==['*']): objs_new.append(i)
#     else: pass

#     #print objs_new, list_of_exp
#     objs=objs_new

#     #copy arcs to tmp folder
#     for i in arcs:
#         system("cp %s tmp/arcs/" % (i[0]))

#     #copy objs to tmp folder
#     for i in objs:
#         system("cp %s tmp/objs/" % (i[0]))

# %%
#reduce arcs
iraf.noao(_doprint=0,Stdout="/dev/null")
iraf.imred(_doprint=0,Stdout="/dev/null")
iraf.ccdred(_doprint=0,Stdout="/dev/null")

# %%
iraf.ccdproc(images=arc, ccdtype='', fixpix='no', oversca='no', trim='no', zerocor='yes', darkcor='no', flatcor='no', zero='masterbias',Stdout="/dev/null")

# %%
#reduce object frames
print " + Reducing objects"
iraf.hedit(images=obj, fields='DISPAXIS', value=1, add='yes', verify='no', update='yes',Stdout="/dev/null")
iraf.ccdproc(images=obj, ccdtype='', fixpix='no', oversca='no', trim='no', zerocor='yes', darkcor='no', flatcor='no', zero='masterbias',Stdout="/dev/null")
# Out:
#  + Reducing objects

# %%
#fit and subtract scattered light
print " + Fitting and removing scattered light"
iraf.apscat1.functio='cheb'
iraf.apscat1.sample='10:4090'
iraf.apscat1.order=9
iraf.apscat1.low_rej=4
iraf.apscat1.high_rej=1.1
iraf.apscat1.niter=10
iraf.apscat1.grow=0
iraf.apscat1.naverage=-1

iraf.apscat2.functio='cheb'
iraf.apscat2.order=5
iraf.apscat2.sample='1:4095'
iraf.apscat2.low_rej=3
iraf.apscat2.high_rej=3
iraf.apscat2.niter=5
iraf.apscat2.grow=1
iraf.apscat2.naverage=-70
# Out:
#  + Fitting and removing scattered light

# %%
iraf.imcopy(input=obj, output='sct',Stdout="/dev/null")
iraf.apscatter(input=obj, output='', referen='masterflat_norm', interac='no', find='no', recente='no', resize='no', edit='no', trace='no', fittrace='no', subtrac='yes', smooth='yes', fitscat='yes', fitsmoo='yes', buffer=0.7)
# Out:
# WARNING: Reference image (masterflat_norm) apertures not found

# %%
extract(arc, obj, ccd)

# %%
ccd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-d74735605d5e> in <module>()
# ----> 1 ccd
#
# NameError: name 'ccd' is not defined

# %% [markdown]
# ### IRAF CC tests

# %%
import pyfits as pf
import pylab as plt

# %%
cd ~/Documents/HERMES/reductions/iraf/HD1581/cam1/
# Out:
# /Users/Carlos/Documents/HERMES/reductions/iraf/HD1581/cam1

# %%
cd ~/Documents/workspace/GAP/IrafReduction/results/140820/norm/
# Out:
# /Users/Carlos/Documents/workspace/GAP/IrafReduction/results/140820/norm

# %%
a = pf.open('20aug10053.fits')

# %%
cd ~/Documents/workspace/GAP/IrafReduction/results/140821/norm/
# Out:
# /Users/Carlos/Documents/workspace/GAP/IrafReduction/results/140821/norm

# %%
b = pf.open('22aug10038.fits')

# %%
import numpy as np
def get_wl(header, app):
    WS = 'WS_'+str(app)
    WD = 'WD_'+str(app)

    first_px = float(header[WS])
    disp = float(header[WD])
    length = header['NAXIS1']
    wl = np.arange(length)*disp
    wl += first_px
    
    return wl

# %%
def plot_app(fits1, fits2 ,app):
    plt.plot(get_wl(fits1[0].header, app),fits1[0].data[app])
    plt.plot(get_wl(fits2[0].header, app),fits2[0].data[app])
    plt.show()
    
#     plt.plot(get_wl(fits1[0].header,app), '.' )
#     plt.plot(get_wl(fits2[0].header,app), '.')
#     plt.show()
    
#     wl1=get_wl(fits1[0].header,app)
#     wl2=get_wl(fits2[0].header,app)    
#     print wl1-wl2

# %%
plot_app(a,b,173)
# plot_app(b,223)

# %%
import RVTools as RVT
from scipy import signal

# %%
flux1 = a[0].data[173]
wl1 = get_wl(a[0].header, 173)
flux2b = b[0].data[173]
wl2 = get_wl(b[0].header, 173)

# flux2 = np.interp(wl2, wl2, flux2b)
flux2 = np.interp(wl1, wl2, flux2b)
flux1 = np.interp(wl1, wl1, flux1)

# %%
plt.plot(wl2,flux2b,marker='+')
plt.scatter(wl1,flux2, marker = '+', s=200, c='r')
plt.show()

# %%
flux2
# Out:
# array([ 1.00160375,  1.01409539,  0.9891579 , ...,  1.07438214,
#         0.95522711,  0.456856  ])

# %%
plt.plot(signal.fftconvolve(flux1, flux2[::-1], mode='same'))
plt.show()

# %%
corrHWidth =3

# %%
CCCurve = []
CCCurve = signal.fftconvolve(flux1[-np.isnan(flux1)], flux2[-np.isnan(flux2)][::-1], mode='same')
corrMax = np.where(CCCurve==max(CCCurve))[0][0]
p_guess = [corrMax,corrHWidth]
x_mask = np.arange(corrMax-corrHWidth, corrMax+corrHWidth+1)
if max(x_mask)<len(CCCurve):
#                 try:
#                 print '4 params',p_guess, x_mask, np.sum(x_mask), CCCurve.shape
    p = RVT.fit_gaussian(p_guess, CCCurve[x_mask], np.arange(len(CCCurve))[x_mask])[0]
    if np.modf(CCCurve.shape[0]/2.0)[0]>1e-5:
        pixelShift = (p[0]-(CCCurve.shape[0]-1)/2.) #odd number of elements
    else:
        pixelShift = (p[0]-(CCCurve.shape[0])/2.) #even number of elements
#                 except:
#                     pixelShift = 0

#     thisQ, thisdRV = QdRV(thisCam.wavelengths[epoch], thisCam.red_fluxes[epoch])

    mid_px = flux1.shape[0]/2
    dWl = (wl1[mid_px+1]-wl1[mid_px]) / wl1[mid_px]
    RV = dWl * pixelShift * RVT.constants.c 
    print 'RV',RV
# Out:
# RV -105.193623917

# %%
cd /Users/Carlos/Documents/HERMES/reductions/6.5/HD285507_1arc/npy/
# Out:
# /Users/Carlos/Documents/HERMES/reductions/6.5/HD285507_1arc/npy

# %%
data = np.load('data.npy')

# %%
data
# Out:
# array([['Field22', '8.87', '0.0', '62.0508', '16.0182'],
#        ['Giant35', '8.1', '3.0', '62.7275', '15.2627'],
#        ['Field32', '6.24', '6.0', '62.6704', '15.2370'],
#        ['Giant16', '8.99', '13.0', '62.4287', '15.1821'],
#        ['Giant12', '7.36', '14.0', '62.3204', '15.2008'],
#        ['Giant28', '8.4', '16.0', '62.6095', '15.1044'],
#        ['Giant08', '8.97', '30.0', '62.1862', '15.1133'],
#        ['Field05', '5.03', '47.0', '61.925', '15.1627'],
#        ['Giant02', '6.44', '52.0', '61.8854', '15.1958'],
#        ['Field16', '4.81', '55.0', '62.1195', '14.8940'],
#        ['Field24', '4.14', '61.0', '62.1975', '14.7010'],
#        ['Field34', '8.41', '66.0', '62.2195', '14.5467'],
#        ['Field08', '7.56', '74.0', '61.8925', '14.9866'],
#        ['Giant36', '6.64', '75.0', '62.1075', '14.4573'],
#        ['Field28', '8.03', '77.0', '62.0675', '14.5516'],
#        ['Field19', '6.56', '316.0', '61.9583', '16.0199'],
#        ['Giant19', '6.12', '319.0', '62.0325', '16.0247'],
#        ['Giant11', '7.47', '320.0', '61.9291', '15.8441'],
#        ['Giant21', '7.09', '322.0', '62.0483', '16.0580'],
#        ['Field37', '5.79', '323.0', '62.1370', '16.2338'],
#        ['Field33', '5.38', '330.0', '62.1875', '16.1231'],
#        ['Field41', '8.94', '337.0', '62.3358', '16.1591'],
#        ['Giant23', '7.04', '341.0', '62.2641', '15.9649'],
#        ['Field42', '7.28', '354.0', '62.5466', '15.9771'],
#        ['Field35', '8.77', '356.0', '62.5095', '15.9136'],
#        ['Field31', '8.11', '357.0', '62.4845', '15.8681'],
#        ['Giant20', '8.09', '366.0', '62.4545', '15.7201']],
#       dtype='|S7')

# %%
a1 = a[0]

# %%
a1.header.items()
# Out:
# [('SIMPLE', True),
#  ('BITPIX', -32),
#  ('NAXIS', 2),
#  ('NAXIS1', 4096),
#  ('NAXIS2', 392),
#  ('EXTEND', True),
#  ('ORIGIN', 'NOAO-IRAF FITS Image Kernel July 2003'),
#  ('DATE', '2015-07-15T09:52:42'),
#  ('IRAF-TLM', '2015-07-15T09:52:39'),
#  ('OBJECT', 'HD1581 #176 (Pivot 175)'),
#  ('COMMENT',
#   "  FITS (Flexible Image Transport System) format is defined in 'Astronomy"),
#  ('COMMENT',
#   "  FITS (Flexible Image Transport System) format is defined in 'Astronomy"),
#  ('LONGSTRN', 'OGIP 1.0'),
#  ('COMMENT',
#   "  FITS (Flexible Image Transport System) format is defined in 'Astronomy"),
#  ('COMMENT',
#   "  FITS (Flexible Image Transport System) format is defined in 'Astronomy"),
#  ('COMMENT',
#   "  FITS (Flexible Image Transport System) format is defined in 'Astronomy"),
#  ('COMMENT',
#   "  FITS (Flexible Image Transport System) format is defined in 'Astronomy"),
#  ('DCT_DATE', 'Oct  9 2013'),
#  ('DCT_VER', 'r3_138'),
#  ('DETECXE', 4096),
#  ('DETECXS', 1),
#  ('DETECYE', 4112),
#  ('DETECYS', 1),
#  ('FIRMVSYS', 'System: AAO2 CCD Controller System Controller V1.28 130312'),
#  ('FIRMVSEQ', 'Sequencer: AAO2 CCD Controller Sequencer V1.3 110321'),
#  ('DETECTOR', 'E2V5-B'),
#  ('XPIXSIZE', 15.0),
#  ('YPIXSIZE', 15.0),
#  ('CONFIGID', 13),
#  ('DETECTID', 13),
#  ('ABCKPLID', 6),
#  ('VIDPBID', 7),
#  ('CLKPBID', 21),
#  ('BRDID_1', 65537),
#  ('BRDSN_1', 18),
#  ('BRDID_2', 327681),
#  ('BRDSN_2', 19),
#  ('BRDID_3', 131074),
#  ('BRDSN_3', 89),
#  ('BRDID_4', 131074),
#  ('BRDSN_4', 119),
#  ('BRDID_5', 131074),
#  ('BRDSN_5', 109),
#  ('BRDID_6', 131074),
#  ('BRDSN_6', 110),
#  ('BRDID_7', 196610),
#  ('BRDSN_7', 98),
#  ('BRDID_8', 262146),
#  ('BRDSN_8', 78),
#  ('BRDID_9', 458754),
#  ('BRDSN_9', 102),
#  ('BRDID_10', 393217),
#  ('BRDSN_10', 129),
#  ('METHOD', 'Normal ccd control method'),
#  ('SPEED', 'FAST'),
#  ('READAMP', 'LEFT_TWO'),
#  ('EXPOSED', 120.0),
#  ('ELAPSED', 120.5),
#  ('TOTALEXP', 240.5),
#  ('RO_GAIN', 2.7),
#  ('RO_NOISE', 4.0),
#  ('DETTEMP', 167.7141),
#  ('HTRVOLTS', 9.563658),
#  ('SPECTID', 'BL'),
#  ('SFILT1', ' '),
#  ('SFILT2', ' '),
#  ('TELESCOP', 'Anglo-Australian Telescope'),
#  ('ALT_OBS', 1164),
#  ('LAT_OBS', -31.27704),
#  ('LONG_OBS', 149.0661),
#  ('RCT_VER', 'r3_71HB'),
#  ('RCT_DATE', '19-Oct-2013'),
#  ('RUNCMD', 'RUN'),
#  ('RADECSYS', 'FK5'),
#  ('EQUINOX', 2000.0),
#  ('INSTRUME', 'HERMES-2dF'),
#  ('TDFCTVER', 'r11_27'),
#  ('TDFCTDAT', '10-Jun-2014'),
#  ('AAOMOSFT', 1),
#  ('NDFCLASS', 'MFOBJECT'),
#  ('CFG_FILE', 'rhoTucNew_p0.sds'),
#  ('PARKMASK', False),
#  ('TDFCTEVT', '40'),
#  ('DUMMY', 0),
#  ('FLAPS', 'OPEN'),
#  ('RUN', 53),
#  ('OBSNUM', 53),
#  ('GRPNUM', 53),
#  ('GRPMEM', 1),
#  ('GRPMAX', 0),
#  ('OBSTYPE', 'OBJECT'),
#  ('UTDATE', '2014:08:20'),
#  ('EPOCH', 2014.63466127089),
#  ('UTSTART', '19:26:27'),
#  ('UTEND', '19:28:27'),
#  ('STSTART', '03:18:55'),
#  ('STEND', '03:20:56'),
#  ('UTMJD', 56889.8100291911),
#  ('TOPEND', '2DF'),
#  ('AXIS', 'A'),
#  ('AXIS_X', -2.47739791046973e-05),
#  ('AXIS_Y', -0.000109034596881535),
#  ('TRACKING', 'TRACKING'),
#  ('TELFOC', 40.12),
#  ('MEANRA', 5.02704168586666),
#  ('MEANDEC', -64.868515716065),
#  ('TEL_PA', 89.9936044048113),
#  ('HASTART', 44.523032463809),
#  ('ZDSTART', 43.1712046360441),
#  ('APPRA', 0.0908546166102642),
#  ('APPDEC', -1.13067486366481),
#  ('WINDOW', 'HERMES_2ROs_LR'),
#  ('HARTMANA', 'Open'),
#  ('HARTMANB', 'Open'),
#  ('DCHROIC1', 'GA Blue'),
#  ('DCHROIC2', 'GA Green'),
#  ('DCHROIC3', 'GA Red'),
#  ('ELECTEMP', 18.7),
#  ('SPEC1TMP', 19.5),
#  ('SPEC2TMP', 19.3),
#  ('FRM1TEMP', 17.5),
#  ('FRM2TEMP', 17.9),
#  ('SLITTEMP', 18.5),
#  ('SLITMASK', 'OUT'),
#  ('HPOSCONF', 'YES'),
#  ('SLITDITH', 'OFF'),
#  ('SOURCE', 'Plate 0'),
#  ('PISTON', 3193.97619047619),
#  ('TILTSPEC', 8003.06457326562),
#  ('TILTSPAT', 0),
#  ('GRATID', '0'),
#  ('GRATTILT', 0),
#  ('GRATLPMM', 3827.0),
#  ('ORDER', 1),
#  ('DISPENC', 0),
#  ('CAMENC', 0),
#  ('GRATANGL', 0),
#  ('GRATANGR', 0),
#  ('CAMANGL', 0),
#  ('CAMANGR', 0),
#  ('LAMBDAC', 4833.0),
#  ('LAMBDAB', 4833.0),
#  ('LAMBDCR', 4833.0),
#  ('LAMBDBR', 4833.0),
#  ('DISPERS', 0.045),
#  ('SPLYTEMP', 16.4),
#  ('RTRNTEMP', 3.8),
#  ('CAMRTEMP', 14.6),
#  ('HAEND', 45.0280898119029),
#  ('ZDEND', 43.3602034015737),
#  ('WINDOXS1', 1),
#  ('WINDOXE1', 4096),
#  ('WINDOYS1', 1),
#  ('WINDOYE1', 2056),
#  ('WINDOXS2', 4100),
#  ('WINDOXE2', 4149),
#  ('WINDOYS2', 1),
#  ('WINDOYE2', 2056),
#  ('XEFFSIZE', 15.0),
#  ('YEFFSIZE', 15.0),
#  ('RO_GAIN1', 2.6),
#  ('RO_NOIS1', 4.1),
#  ('FILEORIG', '/data/aatobs/OptDet_data/140820/ccd_1/20aug10053.fits'),
#  ('WCSDIM', 2),
#  ('LTM1_1', 1.0),
#  ('WAT0_001', 'system=multispec'),
#  ('WAT1_001',
#   'wtype=multispec label=Wavelength units=angstroms units_display=angst'),
#  ('ZEROCOR', 'Jul 15 14:31 Zero level correction image is tmp/masterbias'),
#  ('CCDSEC', '[1:4146,1:4112]'),
#  ('CCDMEANT', 1121437880),
#  ('CCDPROC', 'Jul 15 14:31 CCD processing done'),
#  ('APSCATTE', 'Scattered light subtracted'),
#  ('CTYPE1', 'MULTISPE'),
#  ('CDELT1', 1.0),
#  ('CD1_1', 1.0),
#  ('BANDID1', 'spectrum - background none, weights none, clean no'),
#  ('CTYPE2', 'MULTISPE'),
#  ('CDELT2', 1.0),
#  ('CD2_2', 1.0),
#  ('LTM2_2', 1.0),
#  ('WAT2_001',
#   'wtype=multispec spec1 = "1 1 0 4714.1924533111 0.045989608062305 414'),
#  ('WAT2_002',
#   '6 0. 27.55 33.55" spec2 = "2 2 0 4714.4096574671 0.045990828245989 4'),
#  ('WAT2_003',
#   '146 0. 35.68 41.68" spec3 = "3 3 0 4714.1568829879 0.045988287036667'),
#  ('WAT2_004',
#   ' 4146 0. 43.58 49.58" spec4 = "4 4 0 4714.1330076946 0.0459906655945'),
#  ('WAT2_005',
#   '44 4146 0. 52.08 58.08" spec5 = "5 5 0 4714.357988942 0.045991027315'),
#  ('WAT2_006',
#   '268 4146 0. 59.85 65.85" spec6 = "6 6 0 4714.0965378584 0.0459941950'),
#  ('WAT2_007',
#   '29094 4146 0. 68.17 74.17" spec7 = "7 7 0 4714.0997201451 0.04598852'),
#  ('WAT2_008',
#   '1027304 4146 0. 76.31 82.31" spec8 = "8 8 0 4714.0572147629 0.045991'),
#  ('WAT2_009',
#   '122331566 4146 0. 84.42 90.42" spec9 = "9 9 0 4714.0219781128 0.0459'),
#  ('WAT2_010',
#   '9382941142 4146 0. 92.46 98.46" spec10 = "10 10 0 4713.9940246961 0.'),
#  ('WAT2_011',
#   '04599665800909 4146 0. 100.64 106.64" spec11 = "11 11 0 4714.1238331'),
#  ('WAT2_012',
#   '225 0.045993104737131 4146 0. 122.71 128.71" spec12 = "12 12 0 4714.'),
#  ('WAT2_013',
#   '3747374406 0.045995914852427 4146 0. 130.90 136.90" spec13 = "13 13'),
#  ('WAT2_014',
#   '0 4714.1084259727 0.045990907585259 4146 0. 139.15 145.15" spec14 ='),
#  ('WAT2_015',
#   '"14 14 0 4714.3427489084 0.045995270503768 4146 0. 147.27 153.27" sp'),
#  ('WAT2_016',
#   'ec15 = "15 15 0 4714.3409545667 0.04598859294315 4146 0. 155.49 161.'),
#  ('WAT2_017',
#   '49" spec16 = "16 16 0 4714.299806214 0.045994889920202 4146 0. 163.9'),
#  ('WAT2_018',
#   '1 169.91" spec17 = "17 17 0 4714.2843592706 0.045994598009516 4146 0'),
#  ('WAT2_019',
#   '. 171.94 177.94" spec18 = "18 18 0 4714.0408553942 0.045983292084249'),
#  ('WAT2_020',
#   ' 4146 0. 180.26 186.26" spec19 = "19 19 0 4714.2529575257 0.04599858'),
#  ('WAT2_021',
#   '9169179 4146 0. 188.64 194.64" spec20 = "20 20 0 4713.9805315013 0.0'),
#  ('WAT2_022',
#   '45990703321191 4146 0. 196.88 202.88" spec21 = "21 21 0 4713.9990746'),
#  ('WAT2_023',
#   '138 0.045993502710873 4146 0. 216.80 222.80" spec22 = "22 22 0 4714.'),
#  ('WAT2_024',
#   '2223141844 0.04600881950633 4146 0. 225.12 231.12" spec23 = "23 23 0'),
#  ('WAT2_025',
#   ' 4713.9621090988 0.045997788320999 4146 0. 233.57 239.57" spec24 = "'),
#  ('WAT2_026',
#   '24 24 0 4713.9577566525 0.045998633953379 4146 0. 242.17 248.17" spe'),
#  ('WAT2_027',
#   'c25 = "25 25 0 4714.1863407871 0.046008287081464 4146 0. 250.61 256.'),
#  ('WAT2_028',
#   '61" spec26 = "26 26 0 4713.9240225686 0.045996761814237 4146 0. 258.'),
#  ('WAT2_029',
#   '99 264.99" spec27 = "27 27 0 4713.8972132696 0.045997607474958 4146'),
#  ('WAT2_030',
#   '0. 267.29 273.29" spec28 = "28 28 0 4713.9098699829 0.04599546102452'),
#  ('WAT2_031',
#   '4 4146 0. 275.75 281.75" spec29 = "29 29 0 4713.8747165092 0.0459986'),
#  ('WAT2_032',
#   '9845849 4146 0. 284.21 290.21" spec30 = "30 30 0 4713.8196098594 0.0'),
#  ('WAT2_033',
#   '4600289555616 4146 0. 292.65 298.65" spec31 = "31 31 0 4713.98078474'),
#  ('WAT2_034',
#   '83 0.045999179030258 4146 0. 314.53 320.53" spec32 = "32 32 0 4713.9'),
#  ('WAT2_035',
#   '60806299 0.04600919759753 4146 0. 323.03 329.03" spec33 = "33 33 0 4'),
#  ('WAT2_280',
#   '170642927 4146 0. 2570.25 2576.25" spec246 = "246 246 0 4713.3038128'),
#  ('WAT2_281',
#   '895 0.046017593709019 4146 0. 2594.40 2600.40" spec247 = "247 247 0'),
#  ('WAT2_282',
#   '4713.3067765032 0.046016472358889 4146 0. 2603.53 2609.53" spec248 ='),
#  ('WAT2_283',
#   ' "248 248 0 4713.290261623 0.046026040429336 4146 0. 2612.68 2618.68'),
#  ('WAT2_284',
#   '" spec249 = "249 249 0 4713.3314630499 0.046018792622342 4146 0. 262'),
#  ('WAT2_285',
#   '1.99 2627.99" spec250 = "250 250 0 4713.582897698 0.046025686522306'),
#  ('WAT2_286',
#   '4146 0. 2631.11 2637.11" spec251 = "251 251 0 4713.5970590081 0.0460'),
#  ('WAT2_287',
#   '2074372865 4146 0. 2640.20 2646.20" spec252 = "252 252 0 4713.353478'),
#  ('WAT2_288',
#   '2398 0.046018762160202 4146 0. 2649.29 2655.29" spec253 = "253 253 0'),
#  ('WAT2_289',
#   ' 4713.5956104471 0.046025383681763 4146 0. 2658.40 2664.40" spec254'),
#  ('WAT2_290',
#   '= "254 254 0 4713.363337104 0.046017114254595 4146 0. 2667.55 2673.5'),
#  ('WAT2_291',
#   '5" spec255 = "255 255 0 4713.3400468014 0.046022414781782 4146 0. 26'),
#  ('WAT2_292',
#   '76.89 2682.89" spec256 = "256 256 0 4713.3010799439 0.04601159191785'),
#  ('WAT2_293',
#   '5 4146 0. 2697.97 2703.97" spec257 = "257 257 0 4713.2802715473 0.04'),
#  ('WAT2_294',
#   '6022596925392 4146 0. 2707.13 2713.13" spec258 = "258 258 0 4713.284'),
#  ('WAT2_295',
#   '5989744 0.046017990361397 4146 0. 2716.41 2722.41" spec259 = "259 25'),
#  ('WAT2_296',
#   '9 0 4713.3101719976 0.046013934055764 4146 0. 2725.74 2731.74" spec2'),
#  ('WAT2_297',
#   '60 = "260 260 0 4713.5508644883 0.04602373877768 4146 0. 2734.84 274'),
#  ('WAT2_298',
#   '0.84" spec261 = "261 261 0 4713.5695283744 0.046017821842402 4146 0.'),
#  ('WAT2_299',
#   ' 2744.14 2750.14" spec262 = "262 262 0 4713.3082733563 0.04601826546'),
#  ('WAT2_300',
#   '8972 4146 0. 2753.39 2759.39" spec263 = "263 263 0 4713.3206240577 0'),
#  ('WAT2_301',
#   '.046018022795709 4146 0. 2762.32 2768.32" spec264 = "264 264 0 4713.'),
#  ('WAT2_302',
#   '3113011663 0.046019712196911 4146 0. 2771.76 2777.76" spec265 = "265'),
#  ('WAT2_303',
#   ' 265 0 4713.2945718687 0.046023801105122 4146 0. 2781.05 2787.05" sp'),
#  ('WAT2_304',
#   'ec266 = "266 266 0 4713.1653734682 0.046015854813006 4146 0. 2803.24'),
#  ('WAT2_305',
#   ' 2809.24" spec267 = "267 267 0 4713.1979136832 0.046014621427247 414'),
#  ('WAT2_306',
#   '6 0. 2812.44 2818.44" spec268 = "268 268 0 4713.1817413471 0.0460181'),
#  ('WAT2_307',
#   '04806665 4146 0. 2821.65 2827.65" spec269 = "269 269 0 4713.17206354'),
#  ('WAT2_308',
#   '38 0.046021839230766 4146 0. 2830.84 2836.84" spec270 = "270 270 0 4'),
#  ('WAT2_309',
#   '713.2227599837 0.046012650943518 4146 0. 2839.99 2845.99" spec271 ='),
#  ('WAT2_310',
#   '"271 271 0 4713.2151394045 0.046018677957238 4146 0. 2849.03 2855.03'),
#  ('WAT2_311',
#   '" spec272 = "272 272 0 4713.2246348679 0.046013310687693 4146 0. 285'),
#  ('WAT2_312',
#   '8.22 2864.22" spec273 = "273 273 0 4713.2270943252 0.046009167888769'),
#  ('WAT2_313',
#   ' 4146 0. 2867.49 2873.49" spec274 = "274 274 0 4713.2211064602 0.046'),
#  ('WAT2_314',
#   '014700878408 4146 0. 2876.57 2882.57" spec275 = "275 275 0 4713.2279'),
#  ('WAT2_315',
#   '558003 0.046015049292463 4146 0. 2885.73 2891.73" spec276 = "276 276'),
#  ('WAT2_316',
#   ' 0 4713.1703553909 0.046016786113236 4146 0. 2907.45 2913.45" spec27'),
#  ('WAT2_317',
#   '7 = "277 277 0 4713.1921167541 0.04601209971442 4146 0. 2916.43 2922'),
#  ('WAT2_318',
#   '.43" spec278 = "278 278 0 4713.1968230319 0.046014288373435 4146 0.'),
#  ('WAT2_319',
#   '2925.48 2931.48" spec279 = "279 279 0 4713.2113379417 0.046013031115'),
#  ('WAT2_320',
#   '196 4146 0. 2934.52 2940.52" spec280 = "280 280 0 4713.2363095327 0.'),
#  ('WAT2_321',
#   '046005207752719 4146 0. 2943.85 2949.85" spec281 = "281 281 0 4713.2'),
#  ('WAT2_322',
#   '063508896 0.046012602092674 4146 0. 2952.60 2958.60" spec282 = "282'),
#  ('WAT2_323',
#   '282 0 4713.4559588454 0.04601803990722 4146 0. 2961.78 2967.78" spec'),
#  ('WAT2_324',
#   '283 = "283 283 0 4713.2192974405 0.046017623903408 4146 0. 2970.74 2'),
#  ('WAT2_325',
#   '976.74" spec284 = "284 284 0 4713.2255027464 0.046015760511662 4146'),
#  ('WAT2_326',
#   '0. 2979.88 2985.87" spec285 = "285 285 0 4713.220278873 0.0460136643'),
#  ('WAT2_327',
#   '86476 4146 0. 2989.01 2995.01" spec286 = "286 286 0 4713.3658003159'),
#  ('WAT2_328',
#   '0.046010754392466 4146 0. 3011.30 3017.30" spec287 = "287 287 0 4713'),
#  ('WAT2_329',
#   '.1199642279 0.046010358409685 4146 0. 3020.26 3026.26" spec288 = "28'),
#  ('WAT2_330',
#   '8 288 0 4713.3627268736 0.046013547266196 4146 0. 3029.41 3035.41" s'),
#  ('WAT2_331',
#   'pec289 = "289 289 0 4713.3801635909 0.046014700131522 4146 0. 3047.1'),
#  ('WAT2_332',
#   '7 3053.17" spec290 = "290 290 0 4713.1444787288 0.046016308284589 41'),
#  ('WAT2_333',
#   '46 0. 3056.29 3062.29" spec291 = "291 291 0 4713.1629901572 0.046009'),
#  ('WAT2_334',
#   '053081386 4146 0. 3065.13 3071.13" spec292 = "292 292 0 4713.1569814'),
#  ('WAT2_335',
#   '438 0.046010867569633 4146 0. 3074.14 3080.14" spec293 = "293 293 0'),
#  ('WAT2_336',
#   '4713.4094331912 0.04601668905153 4146 0. 3083.24 3089.24" spec294 ='),
#  ('WAT2_337',
#   '"294 294 0 4713.1607920974 0.046011572193849 4146 0. 3092.08 3098.08'),
#  ('WAT2_338',
#   '" spec295 = "295 295 0 4713.06843077 0.046009361743068 4146 0. 3115.'),
#  ('WAT2_339',
#   '70 3121.70" spec296 = "296 296 0 4713.3104281811 0.046013736117725 4'),
#  ('WAT2_340',
#   '146 0. 3124.52 3130.52" spec297 = "297 297 0 4713.3316796609 0.04601'),
#  ('WAT2_341',
#   '3691606907 4146 0. 3133.42 3139.42" spec298 = "298 298 0 4713.093419'),
#  ('WAT2_342',
#   '0006 0.046007040233021 4146 0. 3142.43 3148.43" spec299 = "299 299 0'),
#  ('WAT2_343',
#   ' 4713.0873730361 0.046008979784383 4146 0. 3151.32 3157.32" spec300'),
#  ('WAT2_344',
#   '= "300 300 0 4713.1092983083 0.046005793601833 4146 0. 3160.08 3166.'),
#  ('WAT2_345',
#   '08" spec301 = "301 301 0 4713.0544726781 0.046018193277736 4146 0. 3'),
#  ('WAT2_346',
#   '169.00 3175.00" spec302 = "302 302 0 4713.1107788997 0.0460098744017'),
#  ('WAT2_347',
#   '57 4146 0. 3177.93 3183.93" spec303 = "303 303 0 4713.1233904388 0.0'),
#  ('WAT2_348',
#   '46003809052819 4146 0. 3186.92 3192.92" spec304 = "304 304 0 4713.10'),
#  ('WAT2_349',
#   '8898509 0.046010472782013 4146 0. 3195.80 3201.80" spec305 = "305 30'),
#  ('WAT2_350',
#   '5 0 4713.0013648156 0.046013365091403 4146 0. 3218.62 3224.62" spec3'),
#  ('WAT2_351',
#   '06 = "306 306 0 4713.0355868349 0.046006292555734 4146 0. 3227.65 32'),
#  ('WAT2_352',
#   '33.65" spec307 = "307 307 0 4713.027244016 0.046006769342552 4146 0.'),
#  ('WAT2_353',
#   ' 3236.43 3242.43" spec308 = "308 308 0 4713.0365018884 0.04600540226'),
#  ('WAT2_354',
#   '4648 4146 0. 3245.29 3251.29" spec309 = "309 309 0 4713.0371960927 0'),
#  ('WAT2_355',
#   '.046006290708725 4146 0. 3254.16 3260.16" spec310 = "310 310 0 4713.'),
#  ('WAT2_356',
#   '3150632599 0.046005968306649 4146 0. 3262.99 3268.99" spec311 = "311'),
#  ('WAT2_357',
#   ' 311 0 4713.0621101143 0.046000573191181 4146 0. 3272.01 3278.01" sp'),
#  ('WAT2_358',
#   'ec312 = "312 312 0 4713.33449751 0.046000823745386 4146 0. 3280.73 3'),
#  ('WAT2_359',
#   '286.73" spec313 = "313 313 0 4713.0798558116 0.046005346119106 4146'),
#  ('WAT2_360',
#   '0. 3289.64 3295.64" spec314 = "314 314 0 4713.3379792289 0.046001531'),
#  ('WAT2_361',
#   '074518 4146 0. 3298.50 3304.50" spec315 = "315 315 0 4712.9857345983'),
#  ('WAT2_389',
#   '0.045993841001025 4146 0. 3556.41 3562.41" spec339 = "339 339 0 4712'),
#  ('WAT2_390',
#   '.9665222935 0.045986378549227 4146 0. 3565.16 3571.16" spec340 = "34'),
#  ('WAT2_391',
#   '0 340 0 4712.9516428818 0.04598902086743 4146 0. 3573.88 3579.88" sp'),
#  ('WAT2_392',
#   'ec341 = "341 341 0 4712.9617818278 0.045991095094484 4146 0. 3582.70'),
#  ('WAT2_393',
#   ' 3588.70" spec342 = "342 342 0 4713.1408156593 0.046014508364037 414'),
#  ('WAT2_394',
#   '6 0. 3591.29 3597.29" spec343 = "343 343 0 4713.0167651171 0.0459819'),
#  ('WAT2_395',
#   '82746284 4146 0. 3600.15 3606.15" spec344 = "344 344 0 4712.81866926'),
#  ('WAT2_396',
#   '95 0.045994678472256 4146 0. 3622.61 3628.61" spec345 = "345 345 0 4'),
#  ('WAT2_397',
#   '712.8661157602 0.045992739704545 4146 0. 3631.13 3637.13" spec346 ='),
#  ('WAT2_398',
#   '"346 346 0 4712.889859852 0.045988384689692 4146 0. 3639.63 3645.63"'),
#  ('WAT2_399',
#   ' spec347 = "347 347 0 4712.8883960947 0.045993886430637 4146 0. 3648'),
#  ('WAT2_400',
#   '.14 3654.14" spec348 = "348 348 0 4712.9260419713 0.045983739211776'),
#  ('WAT2_401',
#   '4146 0. 3656.64 3662.64" spec349 = "349 349 0 4712.9234921074 0.0459'),
#  ('WAT2_402',
#   '88791556939 4146 0. 3665.19 3671.19" spec350 = "350 350 0 4712.97491'),
#  ('WAT2_403',
#   '6256 0.045983175594553 4146 0. 3673.60 3679.60" spec351 = "351 351 0'),
#  ('WAT2_404',
#   ' 4713.2008315619 0.045992290632307 4146 0. 3682.28 3688.28" spec352'),
#  ('WAT2_405',
#   '= "352 352 0 4712.9740505952 0.045989156985321 4146 0. 3690.70 3696.'),
#  ('WAT2_406',
#   '70" spec353 = "353 353 0 4713.2057152083 0.045997360811481 4146 0. 3'),
#  ('WAT2_407',
#   '699.14 3705.14" spec354 = "354 354 0 4712.8791282616 0.0459802911871'),
#  ('WAT2_408',
#   '06 4146 0. 3720.99 3726.99" spec355 = "355 355 0 4713.1582428091 0.0'),
#  ('WAT2_409',
#   '45983770071772 4146 0. 3729.29 3735.29" spec356 = "356 356 0 4713.17'),
#  ('WAT2_410',
#   '47237673 0.045982479088821 4146 0. 3737.67 3743.67" spec357 = "357 3'),
#  ('WAT2_411',
#   '57 0 4712.9280636149 0.045983632488897 4146 0. 3746.25 3752.25" spec'),
#  ('WAT2_412',
#   '358 = "358 358 0 4712.943737406 0.045984177416279 4146 0. 3754.65 37'),
#  ('WAT2_413',
#   '60.65" spec359 = "359 359 0 4712.9968284348 0.045976158275339 4146 0'),
#  ('WAT2_414',
#   '. 3763.03 3769.03" spec360 = "360 360 0 4713.009000632 0.04598189692'),
#  ('WAT2_415',
#   '6039 4146 0. 3771.42 3777.42" spec361 = "361 361 0 4713.2992726501 0'),
#  ('WAT2_416',
#   '.04597427979762 4146 0. 3779.89 3785.89" spec362 = "362 362 0 4713.2'),
#  ('WAT2_417',
#   '609889639 0.045982740264448 4146 0. 3788.48 3794.48" spec363 = "363'),
#  ('WAT2_418',
#   '363 0 4713.2828934137 0.045981806823975 4146 0. 3796.81 3802.81" spe'),
#  ('WAT2_419',
#   'c364 = "364 364 0 4713.0359272566 0.046007486992299 4146 0. 3818.68'),
#  ('WAT2_420',
#   '3824.68" spec365 = "365 365 0 4713.0930639842 0.045994246219298 4146'),
#  ('WAT2_421',
#   ' 0. 3827.16 3833.16" spec366 = "366 366 0 4712.9311956448 0.04597111'),
#  ('WAT2_422',
#   '2322389 4146 0. 3835.47 3841.47" spec367 = "367 367 0 4712.946374452'),
#  ('WAT2_423',
#   '4 0.045968961944646 4146 0. 3843.89 3849.89" spec368 = "368 368 0 47'),
#  ('WAT2_424',
#   '12.9521855101 0.045976919563784 4146 0. 3852.23 3858.23" spec369 = "'),
#  ('WAT2_425',
#   '369 369 0 4712.9676204404 0.04598011533157 4146 0. 3860.62 3866.62"'),
#  ('WAT2_426',
#   'spec370 = "370 370 0 4713.0052070251 0.045973529358611 4146 0. 3869.'),
#  ('WAT2_427',
#   '05 3875.05" spec371 = "371 371 0 4713.0071148072 0.045980966287945 4'),
#  ('WAT2_428',
#   '146 0. 3877.40 3883.40" spec372 = "372 372 0 4713.0294432803 0.04597'),
#  ('WAT2_429',
#   '7864497253 4146 0. 3885.65 3891.65" spec373 = "373 373 0 4713.032820'),
#  ('WAT2_430',
#   '0536 0.045981514183014 4146 0. 3893.99 3899.99" spec374 = "374 374 0'),
#  ('WAT2_431',
#   ' 4712.8692331091 0.045978310050805 4146 0. 3916.14 3922.14" spec375'),
#  ('WAT2_432',
#   '= "375 375 0 4712.9217943538 0.045971097003588 4146 0. 3924.48 3930.'),
#  ('WAT2_433',
#   '48" spec376 = "376 376 0 4712.8804778178 0.045981125366922 4146 0. 3'),
#  ('WAT2_434',
#   '932.88 3938.88" spec377 = "377 377 0 4712.9124857381 0.0459757754555'),
#  ('WAT2_435',
#   '65 4146 0. 3941.13 3947.12" spec378 = "378 378 0 4712.9198681405 0.0'),
#  ('WAT2_436',
#   '45978841319622 4146 0. 3949.34 3955.34" spec379 = "379 379 0 4712.99'),
#  ('WAT2_437',
#   '20331911 0.04596518860478 4146 0. 3957.75 3963.75" spec380 = "380 38'),
#  ('WAT2_438',
#   '0 0 4713.2270593911 0.045973922696513 4146 0. 3966.01 3972.01" spec3'),
#  ('WAT2_439',
#   '81 = "381 381 0 4713.0077217333 0.045970721682812 4146 0. 3974.31 39'),
#  ('WAT2_440',
#   '80.31" spec382 = "382 382 0 4712.9994114752 0.045981349812812 4146 0'),
#  ('WAT2_441',
#   '. 3982.69 3988.69" spec383 = "383 383 0 4713.2841995509 0.0459740362'),
#  ('WAT2_442',
#   '4866 4146 0. 3990.86 3996.86" spec384 = "384 384 0 4713.0310407501 0'),
#  ('WAT2_443',
#  ('APID326', 'PARKED 0.0'),
#  ('APID327', 'Giant02 8.85'),
#  ('APID328', 'PARKED 0.0'),
#  ('APID329', 'Grid_Sky_16 23.0'),
#  ('APID330', 'PARKED 0.0'),
#  ('APID331', 'PARKED 0.0'),
#  ('APID332', 'Grid_Sky_15 23.0'),
#  ('APID333', 'PARKED 0.0'),
#  ('APID334', 'PARKED 0.0'),
#  ('APID335', 'PARKED 0.0'),
#  ('APID336', 'PARKED 0.0'),
#  ('APID337', 'PARKED 0.0'),
#  ('APID338', 'PARKED 0.0'),
#  ('APID339', 'PARKED 0.0'),
#  ('APID340', 'PARKED 0.0'),
#  ('APID341', 'PARKED 0.0'),
#  ('APID342', 'PARKED 0.0'),
#  ('APID343', 'PARKED 0.0'),
#  ('APID344', 'Giant09 8.22'),
#  ('APID345', 'PARKED 0.0'),
#  ('APID346', 'PARKED 0.0'),
#  ('APID347', 'Grid_Sky_25 23.0'),
#  ('APID348', 'PARKED 0.0'),
#  ('APID349', 'Grid_Sky_24 23.0'),
#  ('APID350', 'FIBRE NOT IN USE 0.0'),
#  ('APID351', 'PARKED 0.0'),
#  ('APID352', 'PARKED 0.0'),
#  ('APID353', 'PARKED 0.0'),
#  ('APID354', 'Giant06 8.85'),
#  ('APID355', 'PARKED 0.0'),
#  ('APID356', 'PARKED 0.0'),
#  ('APID357', 'PARKED 0.0'),
#  ('APID358', 'Grid_Sky_28 23.0'),
#  ('APID359', 'Grid_Sky_27 23.0'),
#  ('APID360', 'Field27 7.58'),
#  ('APID361', 'PARKED 0.0'),
#  ('APID362', 'PARKED 0.0'),
#  ('APID363', 'PARKED 0.0'),
#  ('APID364', 'PARKED 0.0'),
#  ('APID365', 'PARKED 0.0'),
#  ('APID366', 'PARKED 0.0'),
#  ('APID367', 'PARKED 0.0'),
#  ('APID368', 'PARKED 0.0'),
#  ...]

# %%
'Giany01' in a1.header['APID*']
# Out:
# False

# %%
starNames = []
for fib in a1.header['APID*']:
#     print int(fib.key[4:])-1 ,fib.value,
    if not (('PARKED' in fib.value) or ('Grid_Sky' in fib.value) or ('FIBRE ' in fib.value)): 
        if fib.value.split(' ')[0]=='Giant01':
            print fib.key[4:]
# Out:
# 173

# %%
starNames
# Out:
# ['Field22',
#  'Giant04',
#  'Field23',
#  'Field05',
#  'Field02',
#  'Giant10',
#  'Field34',
#  'Field17',
#  'Giant07',
#  'Field08',
#  'Field19',
#  'Field32',
#  'Field09',
#  'Field21',
#  'Giant01',
#  'Giant03',
#  'Giant11',
#  'Field13',
#  'Giant05',
#  'Field26',
#  'Field25',
#  'Field28',
#  'Field29',
#  'Field24',
#  'Field31',
#  'Field30',
#  'Field15',
#  'Field01',
#  'Field04',
#  'Field11',
#  'Field10',
#  'Field07',
#  'Field18',
#  'Giant02',
#  'Giant09',
#  'Giant06',
#  'Field27',
#  'Field20',
#  'Giant08',
#  'Field33',
#  'Field03',
#  'Giant12',
#  'Field14']

# %%
aaa.value
# Out:
# 'PARKED 0.0'
