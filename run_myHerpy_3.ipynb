# %%
#!/usr/bin/python

import myHerpyTools as MHT 
import os
import numpy as np
import sys
import time
import importlib
import glob
import pylab as plt

# %%
#reduction flags
# ver = '6.5'
booLog = False
useBias = False
copyFiles = False
doReduce = True
overwrite = False
# idxFile = 'no_flat_no_bias.idx'
startFrom = 0 #number of data set to begin with. 0 for beginning. Good for starting half way through if it cancelled
baseFolder='/Users/Carlos/Documents/HERMES/reductions/new_start_6.5'

# -1 for all
reduceSet = -1
reduceCam = np.array([0,1,3]) #don't have wl for 2(red)
targetFolder =''

# %%
dataset = 'HD1581'
dataset = 'HD285507'
dataset = 'rhoTuc'
if 1==1: #len(sys.argv)>1:
# if len(sys.argv)>1:
#     dataset = sys.argv[1]
    try:
        thisDataset = importlib.import_module('data_sets.'+dataset)
    except:
        print 'Could not load dataset:',dataset         
        sys.exit()
    
#     if len(sys.argv)>2:
#         reduceSet = int(sys.argv[2])
#         if len(sys.argv)>3:
#             reduceCam = np.array([int(sys.argv[3])])
            
    #compose file prefixes from date_list
    months = np.array(['', 'jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec'])
    d = np.array([s[4:] for s in thisDataset.date_list])
    m = months[np.array([s[2:4] for s in thisDataset.date_list]).astype(int)]
    filename_prfx = np.core.defchararray.add(d, m)
    dataFolders = np.array([str(i)+'_'+s for i,s in enumerate(filename_prfx)])
    
    if reduceSet==-1: 
        reduceSet = dataFolders
    else:
        reduceSet = dataFolders[reduceSet]

# %%
#HD1581
# 0-0 169
# 0-1 169
# 0-2 169
# 0-3 169
# 0-3 169

# 1-0 169
# 1-1 169
# 1-2 169
# 1-3 169
# 1-4 169

# 2-0 215
# 2-1 168
# 2-2 168
# 2-3 267
# 2-4 169

# 3-0 169
# 3-1 169
# 3-2 169
# 3-3 188
# 3-4 187

goodFibres = np.ones((4,5)).astype(int)*169
goodFibres[2,0] = 215
goodFibres[2,1] = 168
goodFibres[2,2] = 168
goodFibres[2,3] = 267
goodFibres[2,4] = 169

goodFibres[3,0] = 169
goodFibres[3,1] = 169
goodFibres[3,2] = 169
goodFibres[3,3] = 188
goodFibres[3,4] = 187

# %%
# #HD285507
# cam (0-3) - epoch (0-4)
# 0-0 219
# 0-1 219
# 0-2 219
# 0-3 219
# 0-4 219

# 1-0 262
# 1-1 232
# 1-2 245
# 1-3 255
# 1-4 253


# # 2-0 215
# # 2-1 168
# # 2-2 168
# # 2-3 267
# # 2-4 169



# 3-0 218
# 3-1 220
# 3-2 220
# 3-3 218
# 3-4 218

goodFibres = np.ones((4,5)).astype(int)*219
goodFibres[1,0] = 262
goodFibres[1,1] = 232
goodFibres[1,2] = 245
goodFibres[1,3] = 255
goodFibres[1,4] = 253

goodFibres[3,0] = 218
goodFibres[3,1] = 220
goodFibres[3,2] = 220
goodFibres[3,3] = 218
goodFibres[3,4] = 218

# %%
#rhoTuc
# cam (0-3) - epoch (0-4)
# 0-0 169
# 0-1 169
# 0-2 169
# 0-3 169 
# 0-4 169
# 0-5 169
# 0-6 168
# 0-7 168

# 1-0 169
# 1-1 169
# 1-2 169
# 1-3 169
# 1-4 169
# 1-5 169
# 1-6 168
# 1-7 168


# # 2-0 215
# # 2-1 168
# # 2-2 168
# # 2-3 267
# # 2-4 169



# 3-0 218
# 3-1 220
# 3-2 220
# 3-3 218
# 3-4 218

goodFibres = np.ones((4,8)).astype(int)*169
goodFibres[0,6] = 168
goodFibres[0,7] = 168

goodFibres[1,6] = 168
goodFibres[1,7] = 168

goodFibres[3,6] = 168
goodFibres[3,7] = 168

# %%
reload(MHT)

for thisCam in reduceCam:
    
    targetFolder = baseFolder + '/' + dataset + '/' + 'herpy_out' + '/' + str(thisCam)    
    print targetFolder
    
#     #get the initial poly (wls wrt px) to find extended linelist
#     initialWlsFileName = baseFolder + '/initial_wls_' + str(thisCam) + '.txt'
#     initialPoly = MHT.make_poly_from_wls(initialWlsFileName)
    
    #this needs to be the fibre# loop....TODO
    thisFibreIdx = goodFibres[thisCam,0]
    finalLineListFileName = targetFolder + '/final_linelist_' + str(thisCam) + '_fib' +str(thisFibreIdx) + '.txt'
    finalLineList = np.loadtxt(finalLineListFileName)


    pxValuesEpoch = MHT.px_change_across_epochs(finalLineList, glob.glob1(targetFolder,"*arc*"), goodFibres[thisCam], targetFolder)

    
    
    order = 3
    epochPolyFit = []
    epochDiffToFit = []
    #the offsets of 1 epoch per loop
    for i in range(pxValuesEpoch.shape[1]):

        polyFilter = [(pxValuesEpoch[:,i]-pxValuesEpoch[:,0])<100]
#         print pxValuesEpoch[:,i]
        thisEpochPolyFit = np.polyfit(pxValuesEpoch[:,0],(pxValuesEpoch[:,i]-pxValuesEpoch[:,0]), order)
#         thisEpochDiffToFit = np.polynomial.polynomial.polyval(pxValuesEpoch[:,0], thisEpochPolyFit[::-1])-(pxValuesEpoch[:,i]-pxValuesEpoch[:,0])#     plt.plot(pxValuesEpoch[:,0],pxValuesEpoch[:,i]-pxValuesEpoch[:,0], '.')
        
#         plt.plot(pxValuesEpoch[:,0],np.polynomial.polynomial.polyval(pxValuesEpoch[:,0], thisEpochPolyFit[::-1]))
#         plt.plot(pxValuesEpoch[:,0],thisEpochDiffToFit, '.')
#         plt.show()
        
#         print thisEpochPolyFit
        epochPolyFit.append(thisEpochPolyFit)
#         epochDiffToFit.append(thisEpochDiffToFit)

        
        
        
    initialWlsFileName = baseFolder + '/initial_wls_' + str(thisCam) + '.txt'
    refWls = np.loadtxt(initialWlsFileName)

#         print epochPolyFit
    _,wls = MHT.make_WLS_from_polys(refWls, epochPolyFit)
        
        
        
        
#     print "WLS",wls
    
    #load extracted obj and arc and write with the new wls
    for thisSetIdx, thisSet in enumerate([s + '/' + str(thisCam+1) for s in reduceSet]):

        thisFibreIdx = goodFibres[thisCam, thisSetIdx]
        print thisFibreIdx
#         print thisSet 
        fileList = [filename_prfx[thisSetIdx] + str(thisCam+1) + str(name).zfill(4)+ '.fits' for name in thisDataset.ix_array[thisSetIdx]]

        arcFileName=fileList[1] 
        pre = str(thisSetIdx) + '_' + 'arc_s1'
        post = 'cam' + str(thisCam+1)
        extracted_arc = MHT.read_NPY(arcFileName, pre, post, targetFolder)

        for fileIdx, thisFileName in enumerate(fileList[2:]):
            objFileName=thisFileName
            pre = str(thisSetIdx) + '_obj' + str(fileIdx+1) + '_s1'
            post = 'cam' + str(thisCam+1)
            extracted_obj = MHT.read_NPY(objFileName, pre, post, targetFolder)

            if thisCam==10:
                for j in range(thisFibreIdx-10, thisFibreIdx+10):
                    plt.plot(extracted_obj[j], label=str(j))
                    plt.legend(loc=0)
                title = 'Cam:', thisCam,'fib',thisFibreIdx, 'file', objFileName
                plt.title(title)
                plt.show()
            print "wls shape", wls[thisSetIdx].shape
            print "arc shape", extracted_arc.shape
            print "obj shape", extracted_obj.shape
    #         print np.vstack((wls[thisSetIdx], extracted_arc[thisFibreIdx]))
            MHT.write_flux_and_wls(extracted_arc[thisFibreIdx], extracted_obj[thisFibreIdx], wls, thisSetIdx, fileIdx+1, targetFolder)
        
        
        
        
        
#     # get the flux from a single arc
#     objectArc = extracted_arc[thisFibre].copy() 
    
#     # Template to build model from.
# #     lineListfFileName = '../linelist_blue_v3.txt'
        
#     #Create the model, etc
#     thisPoly, thisSolution, thisErr = MHT.make_poly_model_err(objectArc, finalLineListFileName)

#     for thisSetIdx, thisSet in enumerate([s + '/' + str(thisCam+1) for s in reduceSet]):
        
#         print thisSet 
#         fileList = [filename_prfx[thisSetIdx] + str(thisCam+1) + str(name).zfill(4)+ '.fits' for name in thisDataset.ix_array[thisSetIdx]]
#         arcFileName=fileList[1] 
        
#         if thisSetIdx==0:
#             #open arc from epoch 0
#             pre = str(thisSetIdx) + '_' + 'arc_s1'
#             post = 'cam' + str(thisCam+1)

#             extracted_arc = MHT.read_NPY(arcFileName, pre, post, targetFolder)

#             #extend line list to all peaks
#             #creates the new linelist. Wrong, but equally wrong
#             extendedLinelist = MHT.extend_lineList(extracted_arc[thisFibreIdx],initialPoly)
            
            
#             pxValuesEpoch = MHT.px_change_across_epochs(extendedLinelist, glob.glob1(targetFolder,"*arc*"), thisFibreIdx, targetFolder)
            
#             #Calculate differences to fit in order to filter
#             order = 3
#             epochPolyFit = []
#             epochDiffToFit = []
#             #the offsets of 1 epoch per loop
#             for i in range(pxValuesEpoch.shape[1]):
#                 polyFilter = [(pxValuesEpoch[:,i]-pxValuesEpoch[:,0])<10]
#                 thisEpochPolyFit = np.polyfit(pxValuesEpoch[:,0][polyFilter],(pxValuesEpoch[:,i]-pxValuesEpoch[:,0])[polyFilter], order)
#                 thisEpochDiffToFit = np.polynomial.polynomial.polyval(pxValuesEpoch[:,0], thisEpochPolyFit[::-1])-(pxValuesEpoch[:,i]-pxValuesEpoch[:,0])
#                 epochPolyFit.append(thisEpochPolyFit)
#                 epochDiffToFit.append(thisEpochDiffToFit)

#             fibreFilter = np.sum(np.abs(epochDiffToFit)>0.4, axis=0)
# #             print lineList_v2[-fibreFilter.astype(bool)].shape

#             finalLineListFileName = targetFolder + '/final_linelist_' + str(thisCam) + '_fib' +str(thisFibreIdx) + '.txt'
#             np.savetxt(finalLineListFileName, extendedLinelist[-fibreFilter.astype(bool)])
# Out:
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0
# Fibre 169 epoch 0
# Shift between template and this fibre arc 0
# Fibre 169 epoch 1
# Shift between template and this fibre arc 0
# Fibre 169 epoch 2
# Shift between template and this fibre arc 0
# Fibre 169 epoch 3
# Shift between template and this fibre arc 0
# Fibre 169 epoch 4
# Shift between template and this fibre arc 0
# Fibre 169 epoch 5
# Shift between template and this fibre arc 0
# Fibre 169 epoch 6
# Shift between template and this fibre arc 0
# Fibre 169 epoch 7
# Shift between template and this fibre arc 0
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/0_arc_s1_20aug10043_cam1.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/0_obj1_s1_20aug10044_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_0_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_0_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/0_obj2_s1_20aug10045_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_0_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_0_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/0_obj3_s1_20aug10046_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_0_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_0_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/0_obj4_s1_20aug10047_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_0_4.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_0_4.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/0_obj5_s1_20aug10048_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_0_5.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_0_5.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/0_obj6_s1_20aug10049_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_0_6.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_0_6.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/0_obj7_s1_20aug10050_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_0_7.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_0_7.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/0_obj8_s1_20aug10051_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_0_8.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_0_8.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/1_arc_s1_21aug10032_cam1.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/1_obj1_s1_21aug10033_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_1_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_1_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/1_obj2_s1_21aug10034_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_1_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_1_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/1_obj3_s1_21aug10035_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_1_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_1_3.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/2_arc_s1_21aug10046_cam1.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/2_obj1_s1_21aug10044_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_2_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_2_1.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/3_arc_s1_22aug10031_cam1.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/3_obj1_s1_22aug10033_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_3_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_3_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/3_obj2_s1_22aug10034_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_3_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_3_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/3_obj3_s1_22aug10035_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_3_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_3_3.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/4_arc_s1_22aug10045_cam1.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/4_obj1_s1_22aug10046_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_4_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_4_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/4_obj2_s1_22aug10047_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_4_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_4_2.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/5_arc_s1_24aug10054_cam1.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/5_obj1_s1_24aug10055_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_5_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_5_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/5_obj2_s1_24aug10056_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_5_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_5_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/5_obj3_s1_24aug10057_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_5_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_5_3.txt saved.
# 168
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/6_arc_s1_25aug10043_cam1.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/6_obj1_s1_25aug10040_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_6_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_6_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/6_obj2_s1_25aug10041_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_6_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_6_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/6_obj3_s1_25aug10042_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_6_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_6_3.txt saved.
# 168
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/7_arc_s1_25aug10054_cam1.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/7_obj1_s1_25aug10052_cam1.npy read
# wls shape (4096,)
# arc shape (390, 4096)
# obj shape (390, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/HD1581_7_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/0/ThXe_7_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1
# Fibre 169 epoch 0
# Shift between template and this fibre arc 0
# Fibre 169 epoch 1
# Shift between template and this fibre arc 0
# Fibre 169 epoch 2
# Shift between template and this fibre arc 0
# Fibre 169 epoch 3
# Shift between template and this fibre arc 0
# Fibre 169 epoch 4
# Shift between template and this fibre arc 0
# Fibre 169 epoch 5
# Shift between template and this fibre arc 0
# Fibre 169 epoch 6
# Shift between template and this fibre arc 0
# Fibre 169 epoch 7
# Shift between template and this fibre arc 0
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/0_arc_s1_20aug20043_cam2.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/0_obj1_s1_20aug20044_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_0_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_0_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/0_obj2_s1_20aug20045_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_0_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_0_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/0_obj3_s1_20aug20046_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_0_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_0_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/0_obj4_s1_20aug20047_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_0_4.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_0_4.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/0_obj5_s1_20aug20048_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_0_5.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_0_5.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/0_obj6_s1_20aug20049_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_0_6.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_0_6.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/0_obj7_s1_20aug20050_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_0_7.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_0_7.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/0_obj8_s1_20aug20051_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_0_8.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_0_8.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/1_arc_s1_21aug20032_cam2.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/1_obj1_s1_21aug20033_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_1_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_1_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/1_obj2_s1_21aug20034_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_1_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_1_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/1_obj3_s1_21aug20035_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_1_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_1_3.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/2_arc_s1_21aug20046_cam2.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/2_obj1_s1_21aug20044_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_2_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_2_1.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/3_arc_s1_22aug20031_cam2.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/3_obj1_s1_22aug20033_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_3_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_3_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/3_obj2_s1_22aug20034_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_3_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_3_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/3_obj3_s1_22aug20035_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_3_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_3_3.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/4_arc_s1_22aug20045_cam2.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/4_obj1_s1_22aug20046_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_4_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_4_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/4_obj2_s1_22aug20047_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_4_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_4_2.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/5_arc_s1_24aug20054_cam2.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/5_obj1_s1_24aug20055_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_5_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_5_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/5_obj2_s1_24aug20056_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_5_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_5_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/5_obj3_s1_24aug20057_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_5_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_5_3.txt saved.
# 168
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/6_arc_s1_25aug20043_cam2.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/6_obj1_s1_25aug20040_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_6_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_6_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/6_obj2_s1_25aug20041_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_6_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_6_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/6_obj3_s1_25aug20042_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_6_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_6_3.txt saved.
# 168
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/7_arc_s1_25aug20054_cam2.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/7_obj1_s1_25aug20052_cam2.npy read
# wls shape (4096,)
# arc shape (414, 4096)
# obj shape (414, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/HD1581_7_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/1/ThXe_7_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3
# Fibre 169 epoch 0
# Shift between template and this fibre arc 0
# Fibre 169 epoch 1
# Shift between template and this fibre arc 0
# Fibre 169 epoch 2
# Shift between template and this fibre arc 0
# Fibre 169 epoch 3
# Shift between template and this fibre arc 0
# Fibre 169 epoch 4
# Shift between template and this fibre arc 0
# Fibre 169 epoch 5
# Shift between template and this fibre arc 0
# Fibre 169 epoch 6
# Shift between template and this fibre arc 0
# Fibre 169 epoch 7
# Shift between template and this fibre arc 0
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/0_arc_s1_20aug40043_cam4.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/0_obj1_s1_20aug40044_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_0_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_0_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/0_obj2_s1_20aug40045_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_0_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_0_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/0_obj3_s1_20aug40046_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_0_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_0_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/0_obj4_s1_20aug40047_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_0_4.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_0_4.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/0_obj5_s1_20aug40048_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_0_5.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_0_5.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/0_obj6_s1_20aug40049_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_0_6.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_0_6.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/0_obj7_s1_20aug40050_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_0_7.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_0_7.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/0_obj8_s1_20aug40051_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_0_8.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_0_8.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/1_arc_s1_21aug40032_cam4.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/1_obj1_s1_21aug40033_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_1_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_1_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/1_obj2_s1_21aug40034_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_1_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_1_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/1_obj3_s1_21aug40035_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_1_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_1_3.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/2_arc_s1_21aug40046_cam4.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/2_obj1_s1_21aug40044_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_2_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_2_1.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/3_arc_s1_22aug40031_cam4.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/3_obj1_s1_22aug40033_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_3_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_3_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/3_obj2_s1_22aug40034_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_3_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_3_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/3_obj3_s1_22aug40035_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_3_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_3_3.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/4_arc_s1_22aug40045_cam4.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/4_obj1_s1_22aug40046_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_4_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_4_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/4_obj2_s1_22aug40047_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_4_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_4_2.txt saved.
# 169
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/5_arc_s1_24aug40054_cam4.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/5_obj1_s1_24aug40055_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_5_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_5_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/5_obj2_s1_24aug40056_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_5_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_5_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/5_obj3_s1_24aug40057_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_5_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_5_3.txt saved.
# 168
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/6_arc_s1_25aug40043_cam4.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/6_obj1_s1_25aug40040_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_6_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_6_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/6_obj2_s1_25aug40041_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_6_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_6_2.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/6_obj3_s1_25aug40042_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_6_3.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_6_3.txt saved.
# 168
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/7_arc_s1_25aug40054_cam4.npy read
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/7_obj1_s1_25aug40052_cam4.npy read
# wls shape (4096,)
# arc shape (397, 4096)
# obj shape (397, 4096)
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/HD1581_7_1.txt saved.
# /Users/Carlos/Documents/HERMES/reductions/new_start_6.5/rhoTuc/herpy_out/3/ThXe_7_1.txt saved.
