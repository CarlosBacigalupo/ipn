# %%
import glob
import os
import numpy as np
import scipy.constants as const
import commands
# import pyfits as pf\n",
# import toolbox\n",
from scipy import signal, interpolate, optimize, constants
import pylab as plt
import pickle
from red_tools import *
import asteroseismology as ast
import HERMES
# reload(red_tools)\n",
reload(ast)
import carlos

# %%
os.chdir('/Users/Carlos/Documents/HERMES/reductions/m67_all_4cams')

# %%
#below are stars with single plate, single 
# M67-424 14.622 16 good
# M67-429 16.69 10 trouble
# M67-432 15.891 16 good
# M67-457 15.837 16 trouble
# M67-481 15.164 4 
# M67-506 14.109 12
# M67-512 15.656 4
# M67-524 17.72 10
# M67-525 16.36 10
# M67-538 14.679 12
# M67-539 14.307 16
# M67-546 15.272 12
# M67-557 14.327 16
# M67-560 15.038 12
# M67-580 14.735 16
# M67-F-117 12.58 11  good
# M67-I-198 13.141 13
# M67-I-242ble 11.06 11
# M67-S116 13.075 13
# M67-S16 13.063 13
# M67-S174 14.137 16
# M67-S175 16.15 10
# M67-S200 14.965 16
# M67-S203 14.549 16
# M67-S210 16.4 10
# M67-S214 15.364 16
# M67-S218 14.749 16
# M67-S232 14.129 4
# M67-S241 14.118 4
# M67-S247 15.278 4
# M67-S248 15.706 4
# M67-S267 15.73 12
# M67-S27 13.182 13 good
# M67-S272 15.391 16
# M67-S279 14.561 16
# M67-S29 13.28 13
# M67-S293 16.64 10
# M67-S297 14.338 4
# M67-S299 15.898 16
# M67-S317 15.277 4
# M67-S318 14.009 12
# M67-S341 14.345 16
# M67-S342 15.237 4
# M67-S345 16.5 10
# M67-S457 16.38 10
# M67-S484 14.643 16
# M67-S49 12.61 11 good
# M67-S496 15.334 16
# M67-S516 14.246 4
# M67-S523 15.74 12
# M67-S526 14.149 4
# M67-S529 13.586 13
# M67-S538 14.145 4
# M67-S560 15.553 16
# M67-S565 15.764 16
# M67-S572 15.711 4
# M67-S581 14.941 12
# M67-S591 14.407 16
# M67-S607 15.731 12
# M67-S617 15.896 16
# M67-S626 15.648 4
# M67-S632 16.91 10
# M67-S642 15.265 12
# M67-S65 13.254 13
# M67-S654 14.769 16
# M67-S69 13.376 13
# M67-S7 13.181 13 good
# M67-S76 13.358 13

# %%
# thisStar = star('M67-S49', xDef = 100, booWrite = True)

# %%
# #merges files
# filename = 'M67-S484.obj'
# filehandler = open(filename, 'r')
# thisStar = pickle.load(filehandler)
# filehandler2 = open('/Users/Carlos/Documents/HERMES/reductions/m67_all_4cams/xdef_1000/'+filename, 'r')
# thisStar2 = pickle.load(filehandler2)

# thisStar.exposures.cam1_fileNames = thisStar2.exposures.cam1_fileNames
# thisStar.exposures.cam1_fluxes = thisStar2.exposures.cam1_fluxes
# thisStar.exposures.cam1_wavelengths = thisStar2.exposures.cam1_wavelengths

# thisStar.exposures.cam2_fileNames = thisStar2.exposures.cam2_fileNames
# thisStar.exposures.cam2_fluxes = thisStar2.exposures.cam2_fluxes
# thisStar.exposures.cam2_wavelengths = thisStar2.exposures.cam2_wavelengths

# thisStar.exposures.cam3_fileNames = thisStar2.exposures.cam3_fileNames
# thisStar.exposures.cam3_fluxes = thisStar2.exposures.cam3_fluxes
# thisStar.exposures.cam3_wavelengths = thisStar2.exposures.cam3_wavelengths

# thisStar.exposures.cam4_fileNames = thisStar2.exposures.cam4_fileNames
# thisStar.exposures.cam4_fluxes = thisStar2.exposures.cam4_fluxes
# thisStar.exposures.cam4_wavelengths = thisStar2.exposures.cam4_wavelengths

# filehandler2.close()
# thisStar2 = None

# %%
# #open move properties to a camera array based structure (for OLD VERSION obj files)


# thisStar.exposures.abs_BaryVels = thisStar.absBaryVels
# thisStar.exposures.rel_BaryVels = thisStar.baryVels
# delattr(thisStar,'absBaryVels')
# delattr(thisStar,'baryVels')
# delattr(thisStar.exposures,'fibres')
# thisStar.exposures.pivots = np.array(thisStar.exposures.pivots)
# thisStar.exposures.plates = np.array(thisStar.exposures.plates)

# a = camera()
# # a.raw_fluxes = thisStar.exposures.cam1_raw_fluxes
# a.red_fluxes = thisStar.exposures.cam1_fluxes
# a.wavelengths = thisStar.exposures.cam1_wavelengths
# a.fileNames = thisStar.exposures.cam1_fileNames
# a.safe_flag = np.ones(len(a.fileNames)).astype(bool)
# delattr(thisStar.exposures,'cam1_raw_fluxes')
# delattr(thisStar.exposures,'cam1_fluxes')
# delattr(thisStar.exposures,'cam1_wavelengths')
# delattr(thisStar.exposures,'cam1_fileNames')
# delattr(thisStar.exposures,'cam1_RVs')


# b = camera()
# # b.raw_fluxes = thisStar.exposures.cam2_raw_fluxes
# b.red_fluxes = thisStar.exposures.cam2_fluxes
# b.wavelengths = thisStar.exposures.cam2_wavelengths
# b.fileNames = thisStar.exposures.cam2_fileNames
# b.safe_flag = np.ones(len(a.fileNames)).astype(bool)
# delattr(thisStar.exposures,'cam2_raw_fluxes')
# delattr(thisStar.exposures,'cam2_fluxes')
# delattr(thisStar.exposures,'cam2_wavelengths')
# delattr(thisStar.exposures,'cam2_fileNames')
# delattr(thisStar.exposures,'cam2_RVs')

# c = camera()
# # c.raw_fluxes = thisStar.exposures.cam3_raw_fluxes
# c.red_fluxes = thisStar.exposures.cam3_fluxes
# c.wavelengths = thisStar.exposures.cam3_wavelengths
# c.fileNames = thisStar.exposures.cam3_fileNames
# c.safe_flag = np.ones(len(a.fileNames)).astype(bool)
# delattr(thisStar.exposures,'cam3_raw_fluxes')
# delattr(thisStar.exposures,'cam3_fluxes')
# delattr(thisStar.exposures,'cam3_wavelengths')
# delattr(thisStar.exposures,'cam3_fileNames')
# delattr(thisStar.exposures,'cam3_RVs')

# d = camera()
# # d.raw_fluxes = thisStar.exposures.cam4_raw_fluxes
# d.red_fluxes = thisStar.exposures.cam4_fluxes
# d.wavelengths = thisStar.exposures.cam4_wavelengths
# d.fileNames = thisStar.exposures.cam4_fileNames
# d.safe_flag = np.ones(len(a.fileNames)).astype(bool)
# delattr(thisStar.exposures,'cam4_raw_fluxes')
# delattr(thisStar.exposures,'cam4_fluxes')
# delattr(thisStar.exposures,'cam4_wavelengths')
# delattr(thisStar.exposures,'cam4_fileNames')
# delattr(thisStar.exposures,'cam4_RVs')

# thisStar.exposures.cameras = np.array([a,b,c,d])

# %%
data = np.load('data.npy')
starList = data[:,[0,3]][np.argsort(data[:,3].astype(float))]

# %%
starList = glob.glob('bright_stars/*.obj')

# %%
starList
# Out:
# ['bright_stars/M67-F-108.obj',
#  'bright_stars/M67-F-170.obj',
#  'bright_stars/M67-S108.obj',
#  'bright_stars/M67-S11.obj',
#  'bright_stars/M67-S122.obj',
#  'bright_stars/M67-S18.obj',
#  'bright_stars/M67-S285.obj',
#  'bright_stars/M67-S307.obj',
#  'bright_stars/M67-S339.obj',
#  'bright_stars/M67-S39.obj',
#  'bright_stars/M67-S43.obj',
#  'bright_stars/M67-S78.obj',
#  'bright_stars/M67-S82.obj']

# %%
filename = starList[3]
# filename = 'M67-S82.obj'
filehandler = open(filename, 'r')
thisStar = pickle.load(filehandler)

# %%
#step 1 filter the bad spectra for each camera
thisCam = thisStar.exposures.cameras[3]
my_data_mask = ((thisStar.exposures.JDs>56660) & (thisStar.exposures.JDs<56670))
ugly_spec_mask = np.ones(len(thisStar.exposures.JDs)).astype(bool)
ugly_spec_mask[7:13]= False                
thisCam.safe_flag = my_data_mask & ugly_spec_mask

# %%
thisCam.clean_wavelengths
# Out:
# []

# %%
thisCam = thisStar.exposures.cameras[0]

wavelengths = thisCam.wavelengths
fluxes =  thisCam.red_fluxes
wavelengths = thisCam.clean_wavelengths
fluxes =  thisCam.clean_fluxes

fig, ax = plt.subplots()
# for i in np.arange(thisCam.wavelengths.shape[0])[thisCam.safe_flag]:
for i in np.arange(thisCam.clean_wavelengths.shape[0]):
    try:
        d, f = carlos.fit_continuum(wavelengths[i], fluxes[i])
    except: continue
    else:
        ax.plot(d, f+i*10, 'k')
#         ax.plot(d, f*0.05+thisStar.exposures.JDs[i], 'k')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-cd02b0ee75fc> in <module>()
#       8 fig, ax = plt.subplots()
#       9 # for i in np.arange(thisCam.wavelengths.shape[0])[thisCam.safe_flag]:
# ---> 10 for i in np.arange(thisCam.clean_wavelengths.shape[0]):
#      11     try:
#      12         d, f = carlos.fit_continuum(wavelengths[i], fluxes[i])
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
thisCam = thisStar.exposures.cameras[2]
# plt.plot(thisCam.wavelengths[0],thisCam.red_fluxes[0]/np.max(thisCam.red_fluxes[0])-1)
plt.plot(thisCam.clean_mean_wavelength, thisCam.clean_mean_flux)
plt.plot(thisCam.clean_wavelengths[0], thisCam.clean_fluxes[0])
plt.plot(thisCam.clean_wavelengths[5], thisCam.clean_fluxes[5])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-5da2a834baea> in <module>()
#       1 thisCam = thisStar.exposures.cameras[2]
#       2 # plt.plot(thisCam.wavelengths[0],thisCam.red_fluxes[0]/np.max(thisCam.red_fluxes[0])-1)
# ----> 3 plt.plot(thisCam.clean_mean_wavelength, thisCam.clean_mean_flux)
#       4 plt.plot(thisCam.clean_wavelengths[0], thisCam.clean_fluxes[0])
#       5 plt.plot(thisCam.clean_wavelengths[5], thisCam.clean_fluxes[5])
#
# AttributeError: camera instance has no attribute 'clean_mean_wavelength'

# %%
xDef = 10 #resampling point s per pixel
CCMaskWidth = 50 #half width of the cc curve to be gaussian fitted

# %%
# thisCam = thisStar.exposures.cameras[3]
# np.savetxt('red_fluxes_IR.txt',thisCam.red_fluxes)

# %%
flux_mask=[]
for j in range(4):
    thisCam = thisStar.exposures.cameras[j]
    flux_mask.append(np.ones(len(thisCam.wavelengths[0])).astype(bool))
flux_mask[3] = thisCam.wavelengths[3]>7690

# %%
flux_mask
# Out:
# [array([ True,  True,  True, ...,  True,  True,  True], dtype=bool),
#  array([ True,  True,  True, ...,  True,  True,  True], dtype=bool),
#  array([ True,  True,  True, ...,  True,  True,  True], dtype=bool),
#  array([False, False, False, ...,  True,  True,  True], dtype=bool)]

# %%
#Debuging CC - cross correlation - create clean fluxes\n",
def clean_flux(flux, xDef = 1, lambdas = np.array([])):
    '''clean a flux array to cross corralate to determine RV shift
        eliminates NaNs
        moving median to reduce peaks
        optional: increase resolution by xDef times
        
    '''	
    
    #Copy to output in case of no resampling
#     fluxHD = flux
#     newLambdas = lambdas
    
    #clean NaNs and median outliers	
#     flux[np.isnan(flux)] = 0
#     fluxNeat = fluxHD	
    fluxMed = signal.medfilt(flux,5)

    w = np.where(abs((flux-fluxMed)/np.maximum(fluxMed,50)) > 0.4)
    for ix in w[0]:
        flux[ix] = fluxMed[ix]

    #remove trailing zeros, devide by fitted curve (flatten) and apply tukey window
#     flux = np.trim_zeros(flux,'f') 
#     lambdas = lambdas[-len(flux):]
#     flux = np.trim_zeros(flux,'b') 
#     lambdas = lambdas[:len(flux)]
    
    if ((lambdas[-np.isnan(flux)].shape[0]>0) &  (flux[-np.isnan(flux)].shape[0]>0)):
        fFlux = optimize.curve_fit(cubic, lambdas[-np.isnan(flux)], flux[-np.isnan(flux)], p0 = [1,1,1,1])
        fittedCurve = cubic(lambdas, fFlux[0][0], fFlux[0][1], fFlux[0][2], fFlux[0][3])
        flux = flux/fittedCurve-1
        
        flux = flux * tukey(0.1, len(flux))

        #if enough data -> resample
        if ((xDef>1) and (len(lambdas)>0)):
            
            fFlux = interpolate.interp1d(lambdas[-np.isnan(flux)],flux[-np.isnan(flux)]) 
            lambdas = np.linspace(min(lambdas), max(lambdas),(max(lambdas)-min(lambdas))/len(lambdas)/xDef)
            flux = fFlux(lambdas)
#             None
    else:
        fluxWindow = np.array([])
        print 'empty after removing zeros'
        
    return lambdas, flux

def cubic(x,a,b,c,d):
    return a*x**3+b*x**2+c*x+d
    
def tukey(alpha, N):

    tukey = np.zeros(N)
    for i in range(int(alpha*(N-1)/2)):
        tukey[i] = 0.5*(1+np.cos(np.pi*(2*i/alpha/(N-1)-1)))
    for i in range(int(alpha*(N-1)/2),int((N-1)*(1-alpha/2))):
        tukey[i] = 1
    for i in range(int((N-1)*(1-alpha/2)),int((N-1))):
        tukey[i] = 0.5*(1+np.cos(np.pi*(2*i/alpha/(N-1)-2/alpha+1)))
    
    return tukey

#################################################################################################################
#this should raise the flag if no flux....
for j in range(4):
    cleanFluxes = []
    cleanWavelengths = []
    thisCam = thisStar.exposures.cameras[j]
    for i in np.arange(thisStar.exposures.JDs.shape[0]):
        print thisStar.exposures.JDs[i]
        if thisCam.safe_flag[i]==True:
            thisFlux = thisCam.red_fluxes[i][flux_mask[j]]
            thisLambdas = thisCam.wavelengths[i][flux_mask[j]]
            lambdaClean, fluxClean = clean_flux(thisFlux, xDef, thisLambdas)
            cleanFluxes.append(fluxClean)
            cleanWavelengths.append(lambdaClean)
        else:
            cleanFluxes.append(np.zeros(np.sum(flux_mask[j])))
            cleanWavelengths.append(np.zeros(np.sum(flux_mask[j])))
            
    thisCam.clean_fluxes = np.array(cleanFluxes)
    thisCam.clean_wavelengths = np.array(cleanWavelengths)
    print ''
# Out:
# 56643.7091669
# 56643.7169949
# 56643.7248256
# 56664.6068547
# 56664.6147414
# 56664.6226131
# 56664.7240369
# 56666.5633835
# 56666.5712594
# 56666.5994654
# 56666.6073097
# 56666.6890282
# empty after removing zeros
# 56666.6968566
# empty after removing zeros
# 56666.7046887
# empty after removing zeros
# 56695.5228869
# 56695.5376721
# 56695.5524554
# 56696.5455301
# 56696.5603055
# 56696.5750902
# 56697.6071657
# 56697.6149939
# 56697.6228382
# 56699.5835547
# 56699.5983286
# 56699.6131181
# 56699.6278899
# 56699.6462305
# 56699.6610106
#
# 56643.7091669
# 56643.7169949
# 56643.7248256
# 56664.6068547
# 56664.6147414
# 56664.6226131
# 56664.7240369
# 56666.5633835
# 56666.5712594
# 56666.5994654
# 56666.6073097
# 56666.6890282
# 56666.6968566
# 56666.7046887
# 56695.5228869
# 56695.5376721
# 56695.5524554
# 56696.5455301
# 56696.5603055
# 56696.5750902
# 56697.6071657
# 56697.6149939
# 56697.6228382
# 56699.5835547
# 56699.5983286
# 56699.6131181
# 56699.6278899
# 56699.6462305
# 56699.6610106
#
# 56643.7091669
# 56643.7169949
# 56643.7248256
# 56664.6068547
# 56664.6147414
# 56664.6226131
# 56664.7240369
# 56666.5633835
# 56666.5712594
# 56666.5994654
# 56666.6073097
# 56666.6890282
# 56666.6968566
# 56666.7046887
# 56695.5228869
# 56695.5376721
# 56695.5524554
# 56696.5455301
# 56696.5603055
# 56696.5750902
# 56697.6071657
# 56697.6149939
# 56697.6228382
# 56699.5835547
# 56699.5983286
# 56699.6131181
# 56699.6278899
# 56699.6462305
# 56699.6610106
#
# 56643.7091669
# 56643.7169949
# 56643.7248256
# 56664.6068547
# 56664.6147414
# 56664.6226131
# 56664.7240369
# 56666.5633835
# 56666.5712594
# 56666.5994654
# 56666.6073097
# 56666.6890282
# 56666.6968566
# 56666.7046887
# 56695.5228869
# 56695.5376721
# 56695.5524554
# 56696.5455301
# 56696.5603055
# 56696.5750902
# 56697.6071657
# 56697.6149939
# 56697.6228382
# 56699.5835547
# 56699.5983286
# 56699.6131181
# 56699.6278899
# 56699.6462305
# 56699.6610106

# %%
#creates mean and median fluxes for CC (from my data only to keep same pivot and plate)
for j in range(4):
    thisCam = thisStar.exposures.cameras[j]
    thisCam.mean_flux = np.nanmean(thisCam.red_fluxes[thisCam.safe_flag], axis =0)
    thisCam.mean_flux = thisCam.mean_flux[flux_mask[j]]
    
#     thisFlux = thisCam.median_flux
#     thisLambdas = thisCam.wavelengths[0]
#     lambdaClean, fluxClean = clean_flux(thisFlux, xDef, thisLambdas)
#     print(j, thisLambdas[:5]- lambdaClean[:5])
#     thisCam.clean_median_wavelength = lambdaClean
#     thisCam.clean_median_flux = fluxClean
    
    thisFlux = thisCam.mean_flux
    thisLambdas = thisCam.wavelengths[0][flux_mask[j]]
    lambdaClean, fluxClean = clean_flux(thisFlux, xDef, thisLambdas)
    thisCam.clean_mean_wavelength = lambdaClean
    thisCam.clean_mean_flux = fluxClean

# %%
thisCam = thisStar.exposures.cameras[2]
thisCam.clean_fluxes[5]
# Out:
# array([], dtype=float64)

# %%
#Debuging CC - cross correlation - create cross correlation curves FROM MEAN
for j in range(4):
    CCCurves = []
    thisCam = thisStar.exposures.cameras[j]
    for i in range(thisStar.exposures.JDs.shape[0]):
        print thisStar.exposures.JDs[i], 
        flux1 = thisCam.clean_mean_flux
        lamba1 = thisCam.clean_mean_wavelength
        flux2 = thisCam.clean_fluxes[i]
        lamba2 = thisCam.clean_wavelengths[i]
        print i,flux1, flux2
        a = signal.fftconvolve(flux1, flux2[::-1], mode='same')
        CCCurves.append(a)
    thisCam.CCCurves = np.array(CCCurves)
    print ''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-238-00e2364a07d2> in <module>()
#      10         lamba2 = thisCam.clean_wavelengths[i]
#      11         print i,flux1, flux2
# ---> 12         a = signal.fftconvolve(flux1, flux2[::-1], mode='same')
#      13         CCCurves.append(a)
#      14     thisCam.CCCurves = np.array(CCCurves)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/signal/signaltools.pyc in fftconvolve(in1, in2, mode)
#     144     # Always use 2**n-sized FFT
#     145     fsize = 2 ** np.ceil(np.log2(size))
# --> 146     IN1 = fftn(in1, fsize)
#     147     IN1 *= fftn(in2, fsize)
#     148     fslice = tuple([slice(0, int(sz)) for sz in size])
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/fftpack/basic.pyc in fftn(x, shape, axes, overwrite_x)
#     514
#     515     """
# --> 516     return _raw_fftn_dispatch(x, shape, axes, overwrite_x, 1)
#     517
#     518 def _raw_fftn_dispatch(x, shape, axes, overwrite_x, direction):
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/fftpack/basic.pyc in _raw_fftn_dispatch(x, shape, axes, overwrite_x, direction)
#     528
#     529     overwrite_x = overwrite_x or _datacopied(tmp, x)
# --> 530     return _raw_fftnd(tmp,shape,axes,direction,overwrite_x,work_function)
#     531
#     532
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/fftpack/basic.pyc in _raw_fftnd(x, s, axes, direction, overwrite_x, work_function)
#     432     if noaxes:
#     433         for i in axes:
# --> 434             x, copy_made = _fix_shape(x, s[i], i)
#     435             overwrite_x = overwrite_x or copy_made
#     436         return work_function(x,s,direction,overwrite_x=overwrite_x)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/fftpack/basic.pyc in _fix_shape(x, n, axis)
#     131         index[axis] = slice(0,s[axis])
#     132         s[axis] = n
# --> 133         z = zeros(s,x.dtype.char)
#     134         z[index] = x
#     135         return z, True
#
# ValueError: cannot convert float NaN to integer
# 56643.7091669 0 [] [ 0.  0.  0. ...,  0.  0.  0.]
# 56643.7169949 1 [] [ 0.  0.  0. ...,  0.  0.  0.]
# 56643.7248256 2 [] [ 0.  0.  0. ...,  0.  0.  0.]
# 56664.6068547 3 [] []

# %%
# #Debuging CC - cross correlation - create cross correlation curves from epoch 0
# for j in range(4):
#     CCCurves = []
#     thisCam = thisStar.exposures.cameras[j]
#     for i in range(thisStar.exposures.JDs.shape[0]):
#         print thisStar.exposures.JDs[i], 
#         flux1 = thisCam.clean_fluxes[0]
#         lamba1 = thisCam.clean_wavelengths[0]
#         flux2 = thisCam.clean_fluxes[i]
#         lamba2 = thisCam.clean_wavelengths[i]
#         a = signal.fftconvolve(flux1, flux2[::-1], mode='same')
#         CCCurves.append(a)
#     thisCam.CCCurves = np.array(CCCurves)
#     print ''

# %%
#Debuging CC - cross correlation - fit gaussian in CCCurves
def gaussian(x, mu, sig, ):
    return np.exp(-np.power(x - mu, 2.) / 2 / np.power(sig, 2.))

def fit_gaussian(p, flux, x_range):
    a = optimize.leastsq(diff_gausian, p, args= [flux, x_range])
    return a

def diff_gausian(p, args):
    
    flux = args[0]
    x_range = args[1]
    diff = gaussian(x_range, p[0],p[1]) - flux/np.max(flux)
    return diff

def get_wavelength(wavelengths, pixel):
    intPx = int(pixel)
    fracPx = pixel - int(pixel)

    return (wavelengths[intPx+1] - wavelengths[intPx])*fracPx + wavelengths[intPx]



###########################################################################################################################
for j in range(4):
    print j
    Ps = []
    shiftedWavelength = []
    sigmas = [] 
    thisCam = thisStar.exposures.cameras[j]
    for i in range(thisStar.exposures.JDs.shape[0]):
        print thisStar.exposures.JDs[i],
        thisCCCurve = thisCam.CCCurves[i]
        if np.sum(thisCCCurve)!=0:
            corrMax = np.where(thisCCCurve==max(thisCCCurve))[0][0]
            p_guess = [corrMax,xDef]
            x_mask = np.arange(corrMax-CCMaskWidth, corrMax+CCMaskWidth+1)
            p = fit_gaussian(p_guess, thisCCCurve[x_mask], np.arange(len(thisCCCurve))[x_mask])[0]
            shiftedLambda = get_wavelength(thisCam.clean_wavelengths[i], p[0])
#             Ps.append(p_guess)
            Ps.append(p)
            shiftedWavelength.append(shiftedLambda)
            sigmas.append(np.abs(get_wavelength(thisCam.clean_wavelengths[i], p[0]+p[1])-shiftedLambda)/shiftedLambda*const.c)
        else:
            print 'Flat CC results. Retuning NaNs'
            Ps.append([np.nan,np.nan])
            shiftedWavelength.append(np.nan)
            sigmas.append(np.nan)
            
    thisCam.Ps = np.array(Ps)
    thisCam.shfted_wavelengths = np.array(shiftedWavelength)
    thisCam.sigmas = np.array(sigmas)
    print ''
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-222-261bb063828b> in <module>()
#      37             x_mask = np.arange(corrMax-CCMaskWidth, corrMax+CCMaskWidth+1)
#      38             p = fit_gaussian(p_guess, thisCCCurve[x_mask], np.arange(len(thisCCCurve))[x_mask])[0]
# ---> 39             shiftedLambda = get_wavelength(thisCam.clean_wavelengths[i], p[0])
#      40 #             Ps.append(p_guess)
#      41             Ps.append(p)
#
# <ipython-input-222-261bb063828b> in get_wavelength(wavelengths, pixel)
#      18     fracPx = pixel - int(pixel)
#      19
# ---> 20     return (wavelengths[intPx+1] - wavelengths[intPx])*fracPx + wavelengths[intPx]
#      21
#      22
#
# IndexError: index out of bounds
#  0
# 56643.7091669 Flat CC results. Retuning NaNs
# 56643.7169949 Flat CC results. Retuning NaNs
# 56643.7248256 Flat CC results. Retuning NaNs
# 56664.6068547

# %%
#Creates RVs from shifted_wavelength
for j in range(4):
    testRVs = []
    thisCam = thisStar.exposures.cameras[j]
    for i in range(thisStar.exposures.JDs.shape[0]):
        print thisStar.exposures.JDs[i],
        clean_wavelength_median = np.median(thisCam.clean_wavelengths[i])
        testRVs.append((clean_wavelength_median - thisCam.shfted_wavelengths[i])/clean_wavelength_median*const.c)
    
    thisCam.RVs = np.array(testRVs)
    print ''
# Out:
# 56695.5228869 56695.5376721 56695.5524554 56664.6068547 56664.6147414 56664.6226131 56664.7240369 56696.5455301 56696.5603055 56696.5750902 56697.6071657 56697.6149939 56697.6228382 56666.5633835 56666.5712594 56666.5994654 56666.6073097 56666.6890282 56666.6968566 56666.7046887 56699.5835547 56699.5983286 56699.6131181 56699.6278899 56699.6462305 56699.6610106 56643.7091669 56643.7169949 56643.7248256
# 56695.5228869 56695.5376721 56695.5524554 56664.6068547 56664.6147414 56664.6226131 56664.7240369 56696.5455301 56696.5603055 56696.5750902 56697.6071657 56697.6149939 56697.6228382 56666.5633835 56666.5712594 56666.5994654 56666.6073097 56666.6890282 56666.6968566 56666.7046887 56699.5835547 56699.5983286 56699.6131181 56699.6278899 56699.6462305 56699.6610106 56643.7091669 56643.7169949 56643.7248256
# 56695.5228869 56695.5376721 56695.5524554 56664.6068547 56664.6147414 56664.6226131 56664.7240369 56696.5455301 56696.5603055 56696.5750902 56697.6071657 56697.6149939 56697.6228382 56666.5633835 56666.5712594 56666.5994654 56666.6073097 56666.6890282 56666.6968566 56666.7046887 56699.5835547 56699.5983286 56699.6131181 56699.6278899 56699.6462305 56699.6610106 56643.7091669 56643.7169949 56643.7248256
# 56695.5228869 56695.5376721 56695.5524554 56664.6068547 56664.6147414 56664.6226131 56664.7240369 56696.5455301 56696.5603055 56696.5750902 56697.6071657 56697.6149939 56697.6228382 56666.5633835 56666.5712594 56666.5994654 56666.6073097 56666.6890282 56666.6968566 56666.7046887 56699.5835547 56699.5983286 56699.6131181 56699.6278899 56699.6462305 56699.6610106 56643.7091669 56643.7169949 56643.7248256

# %%
thisCam = thisStar.exposures.cameras[3]
plt.plot(thisCam.clean_wavelengths[0],thisCam.clean_fluxes[0])
plt.plot(thisCam.clean_mean_wavelength,thisCam.clean_mean_flux)
plt.show()

# %%
# thisCam = thisStar.exposures.cameras[1]
# for i in np.arange(len(thisStar.exposures.my_data_mask))[thisStar.exposures.my_data_mask]: #my data index
#     plt.title('Cross Correlation Result'+filehandler.name[:-4]+' - mean vs t'+str(i)+' - RV='+str(thisCam.RVs[i])+' m/s')
#     x_axis = (thisCam.clean_wavelengths[i]-np.median(thisCam.clean_wavelengths[i]))/thisCam.clean_wavelengths[i]*const.c
#     if x_axis.shape == thisCam.CCCurves[i].shape:
#         plt.plot(x_axis, thisCam.CCCurves[i]/np.max(thisCam.CCCurves[i]))
#         plt.plot(x_axis, gaussian(range(len(thisCam.clean_wavelengths[i])), thisCam.Ps[i][0], thisCam.Ps[i][1]), label = 'gaussian fit') 
#         plt.xlabel('RV [m/s]')
#         plt.legend(loc=0)
#         plt.show()

# %%
thisCam=thisStar.exposures.cameras[0]
thisCam.Ps
# Out:
# array([[           nan,            nan],
#        [           nan,            nan],
#        [           nan,            nan],
#        [ 1174.2532049 ,   177.51497182],
#        [ 1175.98638454,   178.86346863],
#        [ 1177.69496151,   178.87732672],
#        [ 1182.5258095 ,   169.98627356],
#        [ 1181.22917944,   175.39029406],
#        [           nan,            nan],
#        [ 1180.06340933,   178.74204739],
#        [ 1186.59753956,   171.14922494],
#        [ 2048.00000004,   573.32466794],
#        [ 2048.00000004,   573.32466794],
#        [ 2048.00000004,   573.32466794],
#        [           nan,            nan],
#        [           nan,            nan],
#        [           nan,            nan],
#        [           nan,            nan],
#        [           nan,            nan],
#        [           nan,            nan],
#        [           nan,            nan],
#        [           nan,            nan],
#        [           nan,            nan],
#        [           nan,            nan],
#        [           nan,            nan],
#        [           nan,            nan],
#        [           nan,            nan],
#        [           nan,            nan],
#        [           nan,            nan]])

# %%
#Creates delta RVs from shifted_wavelength DDRV
for j in range(4):
    thisCam = thisStar.exposures.cameras[j]    
#     sig = np.std(thisCam.RVs[thisStar.exposures.my_data_mask])
#     sigMask = thisCam.RVs[thisStar.exposures.my_data_mask]-np.mean(thisCam.RVs[thisStar.exposures.my_data_mask])<3*sig
    thisCam.DDRVs = thisCam.RVs-np.median(thisCam.RVs[thisCam.safe_flag])

# %%
# delattr(thisStar.exposures.cameras[0],'clean_fluxes')
delattr(thisStar.exposures.cameras[1],'clean_fluxes')
delattr(thisStar.exposures.cameras[2],'clean_fluxes')
delattr(thisStar.exposures.cameras[3],'clean_fluxes')
delattr(thisStar.exposures.cameras[0],'clean_wavelengths')
delattr(thisStar.exposures.cameras[1],'clean_wavelengths')
delattr(thisStar.exposures.cameras[2],'clean_wavelengths')
delattr(thisStar.exposures.cameras[3],'clean_wavelengths')
file_pi = open(filehandler.name, 'w') 
pickle.dump(thisStar, file_pi) 
file_pi.close()
filehandler.close()
thisStar = None

# %%
#^^^^^^^^^^^^^^^^^^^^THis one

# %%
# plt.title(filehandler.name[:-4])
# # plt.plot(thisStar.exposures.JDs, thisStar.exposures.rel_BaryVels, label = 'Barycentric Vel. ')

# thisCam = thisStar.exposures.cameras[0]
# # RVMask = thisStar.exposures.my_data_mask
# RVMask = ((thisStar.exposures.my_data_mask) & (np.abs(thisCam.RVs)<2e4))
# # RVMask = thisCam.safe_flag
# thisCam.safe_flag = RVMask
# plt.scatter(thisStar.exposures.JDs[RVMask], thisCam.RVs[RVMask], label = 'Blue', color ='b' )
# # plt.errorbar(thisStar.exposures.JDs[RVMask], thisCam.DDRVs[RVMask], yerr=thisCam.sigmas[RVMask],fmt='.', label = 'Blue', color ='b' )

# thisCam = thisStar.exposures.cameras[1]
# # RVMask = thisStar.exposures.my_data_mask
# RVMask = ((thisStar.exposures.my_data_mask) & (np.abs(thisCam.RVs)<2e4))
# # RVMask = thisCam.safe_flag
# thisCam.safe_flag = RVMask
# plt.scatter(thisStar.exposures.JDs[RVMask], thisCam.RVs[RVMask], label = 'Green' , color ='g')
# # plt.errorbar(thisStar.exposures.JDs[RVMask], thisCam.RVs[RVMask], yerr=thisCam.sigmas[RVMask],fmt='.', label = 'Green' , color ='g')

# thisCam = thisStar.exposures.cameras[2]
# # RVMask = thisStar.exposures.my_data_mask
# RVMask = ((thisStar.exposures.my_data_mask) & (np.abs(thisCam.RVs)<2e4))
# # RVMask = thisCam.safe_flag
# thisCam.safe_flag = RVMask
# plt.scatter(thisStar.exposures.JDs[RVMask], thisCam.RVs[RVMask], label = 'Red' , color ='r')
# # plt.errorbar(thisStar.exposures.JDs[RVMask], thisCam.RVs[RVMask], yerr=thisCam.sigmas[RVMask],fmt='.', label = 'Red' , color ='r')

# thisCam = thisStar.exposures.cameras[3]
# # RVMask = thisStar.exposures.my_data_mask
# RVMask = ((thisStar.exposures.my_data_mask) & (np.abs(thisCam.RVs)<2e4))
# # RVMask = thisCam.safe_flag
# thisCam.safe_flag = RVMask
# plt.scatter(thisStar.exposures.JDs[RVMask], thisCam.RVs[RVMask], label = 'IR', color ='cyan' )
# # plt.errorbar(thisStar.exposures.JDs[RVMask], thisCam.RVs[RVMask], yerr=thisCam.sigmas[RVMask],fmt='.', label = 'IR', color ='cyan' )
# #

# plt.xlabel('JD')
# plt.ylabel('RV [m/s]')
# plt.legend(loc=0)
# plt.show()

# %%
# plt.title(filehandler.name[:-4])
# # plt.plot(thisStar.exposures.JDs, thisStar.exposures.rel_BaryVels, label = 'Barycentric Vel. ')

# thisCam = thisStar.exposures.cameras[0]
# # RVMask = thisStar.exposures.my_data_mask
# # RVMask = ((thisStar.exposures.my_data_mask) & (np.abs(thisCam.RVs)<50000))
# RVMask = thisCam.safe_flag
# plt.scatter(thisStar.exposures.JDs[RVMask], thisCam.DDRVs[RVMask], label = 'Blue', color ='b' )
# # plt.errorbar(thisStar.exposures.JDs[RVMask], thisCam.DDRVs[RVMask], yerr=thisCam.sigmas[RVMask],fmt='.', label = 'Blue', color ='b' )

# thisCam = thisStar.exposures.cameras[1]
# # RVMask = thisStar.exposures.my_data_mask
# # RVMask = np.abs(thisCam.RVs)<1e6
# RVMask = thisCam.safe_flag
# plt.scatter(thisStar.exposures.JDs[RVMask], thisCam.DDRVs[RVMask], label = 'Green' , color ='g')
# # plt.errorbar(thisStar.exposures.JDs[RVMask], thisCam.RVs[RVMask], yerr=thisCam.sigmas[RVMask],fmt='.', label = 'Green' , color ='g')

# thisCam = thisStar.exposures.cameras[2]
# # RVMask = thisStar.exposures.my_data_mask
# # RVMask = np.abs(thisCam.RVs)<2e5
# RVMask = thisCam.safe_flag
# plt.scatter(thisStar.exposures.JDs[RVMask], thisCam.DDRVs[RVMask], label = 'Red' , color ='r')
# # plt.errorbar(thisStar.exposures.JDs[RVMask], thisCam.RVs[RVMask], yerr=thisCam.sigmas[RVMask],fmt='.', label = 'Red' , color ='r')

# thisCam = thisStar.exposures.cameras[3]
# # RVMask = thisStar.exposures.my_data_mask
# # RVMask = ((thisStar.exposures.my_data_mask) & (np.abs(thisCam.RVs)<20000))
# RVMask = thisCam.safe_flag
# plt.scatter(thisStar.exposures.JDs[RVMask], thisCam.DDRVs[RVMask], label = 'IR', color ='cyan' )
# # plt.errorbar(thisStar.exposures.JDs[RVMask], thisCam.RVs[RVMask], yerr=thisCam.sigmas[RVMask],fmt='.', label = 'IR', color ='cyan' )


# plt.xlabel('JD')
# plt.ylabel('RV [m/s]')
# plt.legend(loc=0)
# plt.show()

# %%
#plots all data
thisCam = thisStar.exposures.cameras[3]
for i in [10]:
    
    fig = plt.gcf()
    fig.suptitle(filehandler.name[:-4]+' - t0 vs t'+str(i)+' - RV='+str(thisCam.RVs[i])+' m/s', fontsize=14)

    plt.subplot(221)
    plt.title('Clean Flux')
    plt.plot(thisCam.clean_wavelengths[i][::50],thisCam.clean_fluxes[i][::50])
    plt.xlabel('Wavelength [ang]')
    plt.ylabel('Flux [Counts]')
    plt.legend(loc=0)
    
    plt.subplot(223)
    plt.title('Clean Flux - Detail')
    plt.plot(thisCam.clean_median_wavelength,thisCam.clean_median_flux, label = 'Median Flux')
    plt.plot(thisCam.clean_wavelengths[i],thisCam.clean_fluxes[i], label = 'Epoch '+str(i))
    plt.axis((4859,4864, -1,1))
    plt.xlabel('Wavelength [ang]')
    plt.ylabel('Flux [Counts]')
    plt.legend(loc=0)

    plt.subplot(222)
    plt.title('Cross Correlation Result')
    plt.plot((thisCam.clean_wavelengths[i]-np.median(thisCam.clean_wavelengths[i]))/thisCam.clean_wavelengths[i]*const.c,thisCam.CCCurves[i]/np.max(thisCam.CCCurves[i]))
    plt.plot((thisCam.clean_wavelengths[i]-np.median(thisCam.clean_wavelengths[i]))/thisCam.clean_wavelengths[i]*const.c,
             gaussian(range(len(thisCam.clean_wavelengths[i])), thisCam.Ps[i][0], thisCam.Ps[i][1]), label = 'gaussian fit') 
    plt.xlabel('RV [m/s]')
    plt.legend(loc=0)
    
    plt.subplot(224)
    plt.title('Cross Correlation Result - Detail')
    plt.plot((thisCam.clean_wavelengths[i]-np.median(thisCam.clean_wavelengths[i]))/thisCam.clean_wavelengths[i]*const.c,thisCam.CCCurves[i]/np.max(thisCam.CCCurves[i]))
    plt.plot((thisCam.clean_wavelengths[i]-np.median(thisCam.clean_wavelengths[i]))/thisCam.clean_wavelengths[i]*const.c,
             gaussian(range(len(thisCam.clean_wavelengths[i])), thisCam.Ps[i][0], thisCam.Ps[i][1]), label = 'gaussian fit') 
    plt.axis((-8000, 8000,0.5,1.1) )
    plt.xlabel('RV [m/s]')
    plt.legend(loc=0)    

    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-207-1d2d17b14614> in <module>()
#       4
#       5     fig = plt.gcf()
# ----> 6     fig.suptitle(filehandler.name[:-4]+' - t0 vs t'+str(i)+' - RV='+str(thisCam.RVs[i])+' m/s', fontsize=14)
#       7
#       8     plt.subplot(221)
#
# IndexError: list index out of range

# %%
#plots all CC fitted gausian results\n",
# for i in range(CCCurves.shape[0]):\n",
thisCam = thisStar.exposures.cameras[0]
for i in range(4,5):
    plt.plot((thisCam.clean_wavelengths[i]-np.median(thisCam.clean_wavelengths[i]))/thisCam.clean_wavelengths[i]*const.c,thisCam.CCCurves[i]/np.max(thisCam.CCCurves[i]))
#     plt.plot((thisCam.clean_wavelengths[i]-np.median(thisCam.clean_wavelengths[i]))/thisCam.clean_wavelengths[i]*const.c,
#              gaussian(range(len(thisCam.clean_wavelengths[i])), thisCam.Ps[i][0], thisCam.Ps[i][1])) 
    plt.xlabel('RV [m/s]')
plt.show()

# %%
#Debuging CC - resampling and cleaning tests
flux1 = thisStar.exposures.cameras[0].red_fluxes[0]
lambda1 = thisStar.exposures.cameras[0].wavelengths[0]
lambda1Clean_10, flux1Clean_10 = clean_flux(flux1, 1, lambda1)
# lambda1Clean_10, flux1Clean_10 = clean_flux(flux1, xDef, lambda1)
# lambda1Clean_100, flux1Clean_100 = clean_flux(flux1, 100, lambda1)\n",
plt.plot(lambda1,flux1/np.max(flux1), label= 'Reduced')
# plt.plot(lambda1Clean_1,flux1Clean_1)
plt.plot(lambda1Clean_10,flux1Clean_10, label= 'Clean')
# plt.plot(lambda1Clean_100,flux1Clean_100)
plt.title('Reduced and Clean flux')
plt.xlabel('Wavelength [Ang.]')
plt.ylabel('Relatuve Flux')
plt.legend(loc=0)
plt.show()
